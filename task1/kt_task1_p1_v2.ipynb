# %%
# !pip install deepxde

# %%
# import tensorflow as tf

# device_name = tf.test.gpu_device_name()
# if device_name != '/device:GPU:0':
#   print(
#       '\n\nThis error most likely means that this notebook is not '
#       'configured to use a GPU.  Change this in Notebook Settings via the '
#       'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
#   raise SystemError('GPU device not found')

# %%
"""Backend supported: tensorflow.compat.v1, tensorflow, pytorch, jax, paddle"""
import deepxde as dde
import matplotlib.pyplot as plt
import numpy as np
# Import tf if using backend tensorflow.compat.v1 or tensorflow
from deepxde.backend import tf
# Import torch if using backend pytorch
# import torch
# Import jax.numpy if using backend jax
# import jax.numpy as jnp
# Import paddle if using backend paddle
# import paddle


def pde(x, y):
    # Most backends
    dy_xx = dde.grad.hessian(y, x)
    # Backend jax
    # dy_xx, _ = dde.grad.hessian(y, x)
    # Use tf.sin for backend tensorflow.compat.v1 or tensorflow
    return -dy_xx - np.pi ** 2 * tf.sin(np.pi * x)
    # Use torch.sin for backend pytorch
    # return -dy_xx - np.pi ** 2 * torch.sin(np.pi * x)
    # Use jax.numpy.sin for backend jax
    # return -dy_xx - np.pi ** 2 * jnp.sin(np.pi * x)
    # Use paddle.sin for backend paddle
    # return -dy_xx - np.pi ** 2 * paddle.sin(np.pi * x)


def boundary(x, on_boundary):
    return on_boundary


def func(x):
    return np.sin(np.pi * x)


geom = dde.geometry.Interval(-1, 1)
bc = dde.icbc.DirichletBC(geom, func, boundary)
data = dde.data.PDE(geom, pde, bc, 16, 2, solution=func, num_test=100)

layer_size = [1] + [50] * 3 + [1]
activation = "tanh"
initializer = "Glorot uniform"
net = dde.nn.FNN(layer_size, activation, initializer)

model = dde.Model(data, net)
model.compile("adam", lr=0.001, metrics=["l2 relative error", "max APE"])

#losshistory, train_state = model.train(iterations=10000)
# Optional: Save the model during training.
checkpointer = dde.callbacks.ModelCheckpoint(
    "model/model", verbose=1, save_better_only=True )
# Optional: Save the movie of the network solution during training.
# ImageMagick (https://imagemagick.org/) is required to generate the movie.
movie = dde.callbacks.MovieDumper(
     "model/movie", [-1], [1], period=100, save_spectrum=True, y_reference=func
  )
losshistory, train_state = model.train(iterations=5000, callbacks=[checkpointer, movie])
#losshistory, train_state = model.train(iterations=5000, callbacks=[checkpointer])

dde.saveplot(losshistory, train_state, issave=True, isplot=True)

# Optional: Restore the saved model with the smallest training loss
model.restore(f"model/model-{train_state.best_step}.ckpt", verbose=1)
# Plot PDE residual
x = geom.uniform_points(1000, True)
y = model.predict(x, operator=pde)
plt.figure()
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("PDE residual")
plt.show()
# Out:
# No backend selected.
# Finding available backend...
# Using backend: tensorflow.compat.v1
# Other supported backends: tensorflow, pytorch, jax, paddle.
# paddle supports more examples now and is recommended.
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Found tensorflow.compat.v1
# Setting the default backend to "tensorflow.compat.v1". You can change it in the ~/.deepxde/config.json file or export the DDE_BACKEND environment variable. Valid options are: tensorflow.compat.v1, tensorflow, pytorch, jax, paddle (all lowercase)
# Enable just-in-time compilation with XLA.
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.059868 s
#
# 'compile' took 0.513520 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [4.61e+01, 7.95e-01]    [5.21e+01, 7.95e-01]    [1.67e+00, 7.48e+08]
# Epoch 1: train loss improved from inf to 4.69e+01, saving model to model/model-1.ckpt ...
#
# 1000      [9.54e-04, 7.94e-07]    [1.08e-03, 7.94e-07]    [7.40e-04, 8.36e+05]
# Epoch 1000: train loss improved from 4.69e+01 to 9.55e-04, saving model to model/model-1000.ckpt ...
#
# 2000      [3.37e-05, 1.00e-07]    [1.38e-04, 1.00e-07]    [3.27e-04, 3.33e+05]
# Epoch 2000: train loss improved from 9.55e-04 to 3.38e-05, saving model to model/model-2000.ckpt ...
#
# 3000      [1.50e-05, 2.68e-09]    [8.08e-05, 2.68e-09]    [9.79e-05, 5.11e+04]
# Epoch 3000: train loss improved from 3.38e-05 to 1.50e-05, saving model to model/model-3000.ckpt ...
#
# 4000      [2.05e-04, 7.97e-06]    [3.23e-04, 7.97e-06]    [2.28e-03, 2.98e+06]
# 5000      [3.56e-05, 5.62e-07]    [1.10e-04, 5.62e-07]    [6.09e-04, 8.28e+05]
#
# Saving the movie of function to model/movie_x.txt, model/movie_y.txt, model/movie_y.gif...
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.
# Saving the movie of spectrum to model/movie_spectrum.txt, model/movie_spectrum.gif...
# WARNING:matplotlib.animation:MovieWriter imagemagick unavailable; using Pillow instead.
# Best model at step 3000:
#   train loss: 1.50e-05
#   test loss: 8.08e-05
#   test metric: [9.79e-05, 5.11e+04]
#
# 'train' took 19.511939 s
#
# Saving loss history to /content/loss.dat ...
# Saving training data to /content/train.dat ...
# Saving test data to /content/test.dat ...
# Restoring model from model/model-3000.ckpt ...

# %%
"""Backend supported: tensorflow.compat.v1, tensorflow, pytorch, jax, paddle"""
import deepxde as dde
import numpy as np
import matplotlib.pyplot as plt
from deepxde.backend import tf
import imageio.v2 as imageio
import matplotlib.ticker as mticker
from matplotlib import colors

#frequencies of solution
a = 1
b = 1
#domain boundaries
xmax = np.pi
ymax = np.pi
xmin = 0
ymin = 0
#number of iterations for training
N_iter = 5000
Nx_points = 100
Ny_points = 100

#precise solution
def u_precise(x):
  return np.sin(a*x[:, 0:1])*np.cos(b*x[:, 1:2])

#right hand side of Laplace equation
def f_right(x):
  return (a**2 + b**2)*tf.sin(a*x[:, 0:1])*tf.cos(b*x[:, 1:2])

def f_r(x):
  return (a**2 + b**2)*np.sin(a*x[:, 0:1])*np.cos(b*x[:, 1:2])

def g(x):
  return np.sin(a*x[:, 0:1])*np.cos(b*x[:, 1:2])

def pde(x, u):
    # Most backends
    du_xx = dde.grad.hessian(u, x, i=0, j=0)
    du_yy = dde.grad.hessian(u, x, i=1, j=1)
    # Backend jax
    # dy_xx, _ = dde.grad.hessian(y, x, i=0, j=0)
    # dy_yy, _ = dde.grad.hessian(y, x, i=1, j=1)
    f = (a**2 + b**2)*tf.sin(a*x[:, 0:1])*tf.cos(b*x[:, 1:2])
    return -du_xx - du_yy - f_right(x)

def boundary(_, on_boundary):
    return on_boundary

def save_movie(training_frames, N_frames, xmin, xmax, ymin, ymax, Nx_points, Ny_points, filename="movie.gif", fps=0.1):
    norm = colors.Normalize(vmin=np.min(training_frames), vmax=np.max(training_frames))
    with imageio.get_writer(filename, mode='I', fps=fps) as writer:
        for i in range(N_frames):
            fig = plt.figure(figsize=(4, 4))
            plt.imshow(training_frames[i:i+1, :].reshape(Nx_points, Ny_points, order = 'F'), extent=[xmin, xmax, ymin, ymax], cmap='jet', norm=norm)
            plt.title(f'Frame {i + 1}, iter {(i + 1) * 200}')
            plt.xlabel("x")
            plt.ylabel("y")
            plt.xticks(ticks = [0, np.pi/2, np.pi], labels = ['0', 'π/2', 'π'])
            #plt.xticklabels(['0', 'π/2', 'π'])
            plt.yticks(ticks = [0, np.pi/2, np.pi], labels = ['0', 'π/2', 'π'])
            #plt.yticklabels(['0', 'π/2', 'π'])
            # Save the plot to a temporary image
            plt.savefig('temp_plot.png', dpi=fig.dpi)
            writer.append_data(imageio.imread('temp_plot.png'))
            plt.close()  # Close the plot to avoid displaying it in interactive environments

    print(f"Movie saved as {filename}")

def predict_u_with_PINN(a, b, xmin, ymin, xmax, ymax, N_iter, Nx_points, Ny_points, call_save_movie = False, fps=0.1):
  geom = dde.geometry.Rectangle([0, 0], [xmax, ymax])
  #for zero boundary-conditions
  #bc = dde.icbc.DirichletBC(geom, lambda x: 0, boundary)
  bc = dde.icbc.DirichletBC(geom, g, boundary)
  data = dde.data.PDE(geom, pde, bc, num_domain=40**2, num_boundary=4*40, num_test=300, solution = u_precise)
  net = dde.nn.FNN([2] + [70] * 4 + [1], "tanh", "Glorot uniform")
  model = dde.Model(data, net)
  model.compile("adam", lr=0.001, metrics = ["l2 relative error"])
  #model.compile("adam", lr=0.001)
  # Optional: Save the model during training.
  checkpointer = dde.callbacks.ModelCheckpoint(
      "model/model", verbose=1, save_better_only=True )
  #model.compile("L-BFGS", metrics = ["l2 relative error"])
  #with tf.device('/device:GPU:0'):

  #Number of points for predicted solution
  x = geom.uniform_points(Nx_points*Ny_points, True)
  #alternative way of creating flat array of points for solution evaluation
  #X, Y = np.meshgrid(np.linspace(xmin, xmax, Nx_points), np.linspace(ymin, ymax, Ny_points))
  #x = np.vstack([X.ravel(order = 'F'), Y.ravel(order = 'F')]).T

  training_frames = np.empty((0, Nx_points*Ny_points))
  if call_save_movie:
      N_frames = N_iter // 200
      for i in range(N_frames):
          losshistory, train_state = model.train(iterations=100, callbacks=[checkpointer])
          U_pred = model.predict(x).T
          training_frames = np.concatenate((training_frames, U_pred), axis=0)
      losshistory, train_state = model.train(iterations=N_iter - N_frames * 200, callbacks=[checkpointer])
      file_name = "movie_" + str(a) + '_' + str(b) + ".gif"
      save_movie(training_frames, training_frames.shape[0], xmin, xmax, ymin, ymax, Nx_points, Ny_points, filename=file_name, fps=fps)
  else:
    losshistory, train_state = model.train(iterations=N_iter, callbacks=[checkpointer])
  dde.saveplot(losshistory, train_state, issave=True, isplot=True)
  # Optional: Restore the saved model with the smallest training loss
  model.restore(f"model/model-{train_state.best_step}.ckpt", verbose=1)

  #u - predicted solution, u_pr - precise solution

  #call model.predict(x, operator=pde) returns residual of the equation! not the solution itself
  u = model.predict(x).reshape(Nx_points, Ny_points, order='F')
  u_pr = u_precise(x).reshape(Nx_points, Ny_points, order='F')
  residual = model.predict(x, operator=pde).reshape(Nx_points, Ny_points, order='F')

  #eps_l2 = np.linalg.norm(u-u_pr)/np.linalg.norm(u_pr)
  eps_l2 = dde.metrics.l2_relative_error(u_pr, u)
  eps_c = np.max(u-u_pr)
  residual_l2 = np.linalg.norm(residual)/np.linalg.norm(f_r(x))
  residual_c = np.max(residual)

  print("eps_l2 = ", eps_l2)
  print("eps_c = ",eps_c)
  print("residual_l2 = ", residual_l2)
  print("residual_c = ", residual_c)

  #save uh in a file
  file_name = "uh_dde_" + str(a) + '_' + str(b) + ".npy"
  np.save(file_name, u)

  return u, u_pr, training_frames

def plot_figures(u, u_pr, xmin, xmax, ymin, ymax, Nx_points, Ny_points):
    fig, axes = plt.subplots(2, 3, figsize=(10, 6), constrained_layout=True)

    # Set colormap
    cmap = 'jet'
    datasets = [u, u_pr, np.abs(u-u_pr)]
    norm = colors.Normalize(vmin=np.min(datasets), vmax=np.max(datasets))

    # Subplot a)
    im1 = axes[0, 0].imshow(u, extent=[xmin, xmax, ymin, ymax], cmap=cmap, norm=norm)
    axes[0, 0].set_title("a) predicted solution")
    axes[0, 0].set_xlabel("x")
    axes[0, 0].set_ylabel("y")
    axes[0, 0].set_xticks([0, np.pi/2, np.pi])
    axes[0, 0].set_xticklabels(['0', 'π/2', 'π'])
    axes[0, 0].set_yticks([0, np.pi/2, np.pi])
    axes[0, 0].set_yticklabels(['0', 'π/2', 'π'])

    # Subplot b)
    im2 = axes[0, 1].imshow(u_pr, extent=[xmin, xmax, ymin, ymax], cmap=cmap, norm=norm)
    axes[0, 1].set_title("b) precise solution")
    axes[0, 1].set_xticks([0, np.pi/2, np.pi])
    axes[0, 1].set_xticklabels(['0', 'π/2', 'π'])
    axes[0, 1].set_yticks([0, np.pi/2, np.pi])
    axes[0, 1].set_yticklabels(['0', 'π/2', 'π'])
    axes[0, 1].set_xlabel("x")
    axes[0, 1].set_ylabel("y")

    # Subplot c)
    im3 = axes[0, 2].imshow(np.abs(u_pr-u), extent=[xmin, xmax, ymin, ymax], cmap=cmap)
    axes[0, 2].set_title("c) difference")
    axes[0, 2].set_xticks([0, np.pi/2, np.pi])
    axes[0, 2].set_xticklabels(['0', 'π/2', 'π'])
    axes[0, 2].set_yticks([0, np.pi/2, np.pi])
    axes[0, 2].set_yticklabels(['0', 'π/2', 'π'])
    axes[0, 2].set_xlabel("x")
    axes[0, 2].set_ylabel("y")

    #colorbar for a), b)
    cbar1 = fig.colorbar(im2, ax=[axes[0, 0], axes[0, 1]],
                          pad=0.04, location='right', fraction = 0.022, ticks = mticker.LinearLocator(numticks = 5 ))
    #colorbar for c)
    cbar2 = fig.colorbar(im3, ax=[axes[0, 2]],
                          pad=0.04, location='right', fraction = 0.053, ticks = mticker.LinearLocator(numticks = 5 ))

    # Subplot d)
    y1 = np.linspace(ymin, ymax, Ny_points)
    #x = 0
    im4 = axes[1, 0].plot(y1, u[:, 0], '--', label = 'pred')
    axes[1, 0].plot(y1, u_pr[:, 0], label = 'true')
    axes[1, 0].legend(loc='upper right')
    axes[1, 0].set_title("d) x = x_min")
    axes[1, 0].set_xticks([0, np.pi/2, np.pi])
    axes[1, 0].set_xticklabels(['0', 'π/2', 'π'])
    axes[1, 0].set_xlabel("y")
    axes[1, 0].set_ylabel("u")

    # Subplot e)
    #x = pi/2
    im5 = axes[1, 1].plot(y1, u[:, Nx_points//2-1], '--', label = 'pred')
    axes[1, 1].plot(y1, u_pr[:, Nx_points//2-1], label = 'true')
    axes[1, 1].legend(loc='upper right')
    axes[1, 1].set_title("e) x = (x_min + x_max)/2")
    axes[1, 1].set_xticks([0, np.pi/2, np.pi])
    axes[1, 1].set_xticklabels(['0', 'π/2', 'π'])
    axes[1, 1].set_xlabel("y")
    axes[1, 1].set_ylabel("u")

    # Subplot f)
    #x = pi
    im6 = axes[1, 2].plot(y1, u[:, Nx_points-1], '--', label = 'pred')
    axes[1, 2].plot(y1, u_pr[:, Nx_points-1], label = 'true')
    axes[1, 2].legend(loc='upper right')
    axes[1, 2].set_title("f) x = x_max")
    axes[1, 2].set_xticks([0, np.pi/2, np.pi])
    axes[1, 2].set_xticklabels(['0', 'π/2', 'π'])
    axes[1, 2].set_xlabel("y")
    axes[1, 2].set_ylabel("u")

# %%
#frequencies of solution
a = 1
b = 1
#domain boundaries
xmax = np.pi
ymax = np.pi
xmin = 0
ymin = 0
#number of iterations for training
N_iter = 5000
Nx_points = 100
Ny_points = 100

u, u_pr, training_frames = predict_u_with_PINN(a, b, xmin, ymin, xmax, ymax, N_iter, Nx_points, Ny_points, call_save_movie=True, fps = 3)
# file_name = "movie_" + str(a) + '_' + str(b) + ".gif"
# save_movie(training_frames, training_frames.shape[0], xmin, xmax, ymin, ymax, Nx_points, Ny_points, filename=file_name, duration=0.6)

plot_figures(u, u_pr, xmin, xmax, ymin, ymax, Nx_points, Ny_points)
# Out:
# Warning: 300 points required, but 324 points sampled.
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.071815 s
#
# 'compile' took 0.685668 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [1.10e+00, 6.90e-01]    [1.09e+00, 6.90e-01]    [1.60e+00]
# Epoch 1: train loss improved from inf to 1.79e+00, saving model to model/model-1.ckpt ...
#
# 100       [9.36e-02, 3.61e-02]    [8.86e-02, 3.61e-02]    [2.62e-01]
# Epoch 100: train loss improved from 1.79e+00 to 1.30e-01, saving model to model/model-100.ckpt ...
#
#
# Best model at step 100:
#   train loss: 1.30e-01
#   test loss: 1.25e-01
#   test metric: [2.62e-01]
#
# 'train' took 2.958226 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 100       [9.36e-02, 3.61e-02]    [8.86e-02, 3.61e-02]    [2.62e-01]
# 200       [3.38e-03, 6.74e-04]    [2.37e-03, 6.74e-04]    [3.52e-02]
# Epoch 200: train loss improved from 1.30e-01 to 4.06e-03, saving model to model/model-200.ckpt ...
#
#
# Best model at step 200:
#   train loss: 4.06e-03
#   test loss: 3.05e-03
#   test metric: [3.52e-02]
#
# 'train' took 0.677857 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 200       [3.38e-03, 6.74e-04]    [2.37e-03, 6.74e-04]    [3.52e-02]
# 300       [2.05e-03, 4.42e-04]    [1.36e-03, 4.42e-04]    [2.86e-02]
# Epoch 300: train loss improved from 4.06e-03 to 2.50e-03, saving model to model/model-300.ckpt ...
#
#
# Best model at step 300:
#   train loss: 2.50e-03
#   test loss: 1.81e-03
#   test metric: [2.86e-02]
#
# 'train' took 0.688304 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 300       [2.05e-03, 4.42e-04]    [1.36e-03, 4.42e-04]    [2.86e-02]
# 400       [1.67e-03, 4.03e-04]    [1.10e-03, 4.03e-04]    [3.37e-02]
# Epoch 400: train loss improved from 2.50e-03 to 2.08e-03, saving model to model/model-400.ckpt ...
#
#
# Best model at step 400:
#   train loss: 2.08e-03
#   test loss: 1.50e-03
#   test metric: [3.37e-02]
#
# 'train' took 0.704902 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 400       [1.67e-03, 4.03e-04]    [1.10e-03, 4.03e-04]    [3.37e-02]
# 500       [1.42e-03, 2.83e-04]    [9.32e-04, 2.83e-04]    [2.47e-02]
# Epoch 500: train loss improved from 2.08e-03 to 1.71e-03, saving model to model/model-500.ckpt ...
#
#
# Best model at step 500:
#   train loss: 1.71e-03
#   test loss: 1.22e-03
#   test metric: [2.47e-02]
#
# 'train' took 0.711040 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 500       [1.42e-03, 2.83e-04]    [9.32e-04, 2.83e-04]    [2.47e-02]
# 600       [1.18e-03, 2.31e-04]    [7.74e-04, 2.31e-04]    [2.07e-02]
# Epoch 600: train loss improved from 1.71e-03 to 1.41e-03, saving model to model/model-600.ckpt ...
#
#
# Best model at step 600:
#   train loss: 1.41e-03
#   test loss: 1.01e-03
#   test metric: [2.07e-02]
#
# 'train' took 0.735424 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 600       [1.18e-03, 2.31e-04]    [7.74e-04, 2.31e-04]    [2.07e-02]
# 700       [8.88e-04, 2.14e-04]    [5.43e-04, 2.14e-04]    [1.97e-02]
# Epoch 700: train loss improved from 1.41e-03 to 1.10e-03, saving model to model/model-700.ckpt ...
#
#
# Best model at step 700:
#   train loss: 1.10e-03
#   test loss: 7.57e-04
#   test metric: [1.97e-02]
#
# 'train' took 0.717761 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 700       [8.88e-04, 2.14e-04]    [5.43e-04, 2.14e-04]    [1.97e-02]
# 800       [6.23e-04, 1.89e-04]    [3.68e-04, 1.89e-04]    [2.05e-02]
# Epoch 800: train loss improved from 1.10e-03 to 8.12e-04, saving model to model/model-800.ckpt ...
#
#
# Best model at step 800:
#   train loss: 8.12e-04
#   test loss: 5.57e-04
#   test metric: [2.05e-02]
#
# 'train' took 0.854869 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 800       [6.23e-04, 1.89e-04]    [3.68e-04, 1.89e-04]    [2.05e-02]
# 900       [4.60e-04, 1.41e-04]    [2.63e-04, 1.41e-04]    [1.58e-02]
# Epoch 900: train loss improved from 8.12e-04 to 6.01e-04, saving model to model/model-900.ckpt ...
#
#
# Best model at step 900:
#   train loss: 6.01e-04
#   test loss: 4.05e-04
#   test metric: [1.58e-02]
#
# 'train' took 1.114562 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 900       [4.60e-04, 1.41e-04]    [2.63e-04, 1.41e-04]    [1.58e-02]
# 1000      [3.75e-04, 1.20e-04]    [2.22e-04, 1.20e-04]    [1.44e-02]
# Epoch 1000: train loss improved from 6.01e-04 to 4.96e-04, saving model to model/model-1000.ckpt ...
#
#
# Best model at step 1000:
#   train loss: 4.96e-04
#   test loss: 3.42e-04
#   test metric: [1.44e-02]
#
# 'train' took 0.941082 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1000      [3.75e-04, 1.20e-04]    [2.22e-04, 1.20e-04]    [1.44e-02]
# 1100      [3.25e-04, 1.04e-04]    [2.04e-04, 1.04e-04]    [1.33e-02]
# Epoch 1100: train loss improved from 4.96e-04 to 4.29e-04, saving model to model/model-1100.ckpt ...
#
#
# Best model at step 1100:
#   train loss: 4.29e-04
#   test loss: 3.08e-04
#   test metric: [1.33e-02]
#
# 'train' took 0.765666 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1100      [3.25e-04, 1.04e-04]    [2.04e-04, 1.04e-04]    [1.33e-02]
# 1200      [2.83e-04, 9.78e-05]    [1.75e-04, 9.78e-05]    [1.30e-02]
# Epoch 1200: train loss improved from 4.29e-04 to 3.80e-04, saving model to model/model-1200.ckpt ...
#
#
# Best model at step 1200:
#   train loss: 3.80e-04
#   test loss: 2.73e-04
#   test metric: [1.30e-02]
#
# 'train' took 0.761077 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1200      [2.83e-04, 9.78e-05]    [1.75e-04, 9.78e-05]    [1.30e-02]
# 1300      [2.51e-04, 9.33e-05]    [1.56e-04, 9.33e-05]    [1.27e-02]
# Epoch 1300: train loss improved from 3.80e-04 to 3.44e-04, saving model to model/model-1300.ckpt ...
#
#
# Best model at step 1300:
#   train loss: 3.44e-04
#   test loss: 2.49e-04
#   test metric: [1.27e-02]
#
# 'train' took 0.752311 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1300      [2.51e-04, 9.33e-05]    [1.56e-04, 9.33e-05]    [1.27e-02]
# 1400      [3.57e-04, 1.64e-03]    [2.58e-04, 1.64e-03]    [8.22e-02]
#
# Best model at step 1300:
#   train loss: 3.44e-04
#   test loss: 2.49e-04
#   test metric: [1.27e-02]
#
# 'train' took 0.631412 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1400      [3.57e-04, 1.64e-03]    [2.58e-04, 1.64e-03]    [8.22e-02]
# 1500      [2.15e-04, 8.38e-05]    [1.41e-04, 8.38e-05]    [1.20e-02]
# Epoch 1500: train loss improved from 3.44e-04 to 2.99e-04, saving model to model/model-1500.ckpt ...
#
#
# Best model at step 1500:
#   train loss: 2.99e-04
#   test loss: 2.25e-04
#   test metric: [1.20e-02]
#
# 'train' took 0.791808 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1500      [2.15e-04, 8.38e-05]    [1.41e-04, 8.38e-05]    [1.20e-02]
# 1600      [1.95e-04, 8.34e-05]    [1.26e-04, 8.34e-05]    [1.20e-02]
# Epoch 1600: train loss improved from 2.99e-04 to 2.78e-04, saving model to model/model-1600.ckpt ...
#
#
# Best model at step 1600:
#   train loss: 2.78e-04
#   test loss: 2.09e-04
#   test metric: [1.20e-02]
#
# 'train' took 0.786932 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1600      [1.95e-04, 8.34e-05]    [1.26e-04, 8.34e-05]    [1.20e-02]
# 1700      [1.79e-04, 8.15e-05]    [1.15e-04, 8.15e-05]    [1.18e-02]
# Epoch 1700: train loss improved from 2.78e-04 to 2.61e-04, saving model to model/model-1700.ckpt ...
#
#
# Best model at step 1700:
#   train loss: 2.61e-04
#   test loss: 1.97e-04
#   test metric: [1.18e-02]
#
# 'train' took 0.800787 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1700      [1.79e-04, 8.15e-05]    [1.15e-04, 8.15e-05]    [1.18e-02]
# 1800      [1.65e-04, 7.92e-05]    [1.06e-04, 7.92e-05]    [1.17e-02]
# Epoch 1800: train loss improved from 2.61e-04 to 2.44e-04, saving model to model/model-1800.ckpt ...
#
#
# Best model at step 1800:
#   train loss: 2.44e-04
#   test loss: 1.85e-04
#   test metric: [1.17e-02]
#
# 'train' took 0.835041 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1800      [1.65e-04, 7.92e-05]    [1.06e-04, 7.92e-05]    [1.17e-02]
# 1900      [1.68e-04, 8.70e-05]    [1.20e-04, 8.70e-05]    [1.33e-02]
#
# Best model at step 1800:
#   train loss: 2.44e-04
#   test loss: 1.85e-04
#   test metric: [1.17e-02]
#
# 'train' took 0.727074 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1900      [1.68e-04, 8.70e-05]    [1.20e-04, 8.70e-05]    [1.33e-02]
# 2000      [1.47e-04, 7.32e-05]    [9.53e-05, 7.32e-05]    [1.12e-02]
# Epoch 2000: train loss improved from 2.44e-04 to 2.20e-04, saving model to model/model-2000.ckpt ...
#
#
# Best model at step 2000:
#   train loss: 2.20e-04
#   test loss: 1.69e-04
#   test metric: [1.12e-02]
#
# 'train' took 0.857097 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2000      [1.47e-04, 7.32e-05]    [9.53e-05, 7.32e-05]    [1.12e-02]
# 2100      [1.34e-04, 7.03e-05]    [8.62e-05, 7.03e-05]    [1.10e-02]
# Epoch 2100: train loss improved from 2.20e-04 to 2.05e-04, saving model to model/model-2100.ckpt ...
#
#
# Best model at step 2100:
#   train loss: 2.05e-04
#   test loss: 1.57e-04
#   test metric: [1.10e-02]
#
# 'train' took 0.860039 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2100      [1.34e-04, 7.03e-05]    [8.62e-05, 7.03e-05]    [1.10e-02]
# 2200      [1.24e-04, 6.70e-05]    [7.80e-05, 6.70e-05]    [1.07e-02]
# Epoch 2200: train loss improved from 2.05e-04 to 1.91e-04, saving model to model/model-2200.ckpt ...
#
#
# Best model at step 2200:
#   train loss: 1.91e-04
#   test loss: 1.45e-04
#   test metric: [1.07e-02]
#
# 'train' took 0.865876 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2200      [1.24e-04, 6.70e-05]    [7.80e-05, 6.70e-05]    [1.07e-02]
# 2300      [1.23e-04, 6.60e-05]    [8.22e-05, 6.60e-05]    [1.04e-02]
# Epoch 2300: train loss improved from 1.91e-04 to 1.89e-04, saving model to model/model-2300.ckpt ...
#
#
# Best model at step 2300:
#   train loss: 1.89e-04
#   test loss: 1.48e-04
#   test metric: [1.04e-02]
#
# 'train' took 1.213548 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2300      [1.23e-04, 6.60e-05]    [8.22e-05, 6.60e-05]    [1.04e-02]
# 2400      [1.07e-04, 6.06e-05]    [6.74e-05, 6.06e-05]    [1.02e-02]
# Epoch 2400: train loss improved from 1.89e-04 to 1.68e-04, saving model to model/model-2400.ckpt ...
#
#
# Best model at step 2400:
#   train loss: 1.68e-04
#   test loss: 1.28e-04
#   test metric: [1.02e-02]
#
# 'train' took 1.187812 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2400      [1.07e-04, 6.06e-05]    [6.74e-05, 6.06e-05]    [1.02e-02]
# 2500      [9.74e-05, 5.68e-05]    [5.96e-05, 5.68e-05]    [9.85e-03]
# Epoch 2500: train loss improved from 1.68e-04 to 1.54e-04, saving model to model/model-2500.ckpt ...
#
#
# Best model at step 2500:
#   train loss: 1.54e-04
#   test loss: 1.16e-04
#   test metric: [9.85e-03]
#
# 'train' took 1.164978 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2500      [9.74e-05, 5.68e-05]    [5.96e-05, 5.68e-05]    [9.85e-03]
#
# Best model at step 2500:
#   train loss: 1.54e-04
#   test loss: 1.16e-04
#   test metric: [9.85e-03]
#
# 'train' took 0.521593 s
#
# Movie saved as movie_1_1.gif
# Saving loss history to /content/loss.dat ...
# Saving training data to /content/train.dat ...
# Saving test data to /content/test.dat ...
# Restoring model from model/model-2500.ckpt ...
#
# eps_l2 =  0.0072720023
# eps_c =  0.019927518
# residual_l2 =  0.008961915
# residual_c =  0.07800016

# %%
# file_name = "movie_" + str(a) + '_' + str(b) + ".gif"
# save_movie(training_frames, training_frames.shape[0], xmin, xmax, ymin, ymax, Nx_points, Ny_points, filename=file_name, fps = 3)
# Out:
# Movie saved as movie_1_1.gif

# %%
#frequencies of solution
a = 2
b = 5
#domain boundaries
xmax = np.pi
ymax = np.pi
xmin = 0
ymin = 0
#number of iterations for training
N_iter = 5000
Nx_points = 100
Ny_points = 100

u, u_pr, training_frames = predict_u_with_PINN(a, b, xmin, ymin, xmax, ymax, N_iter, Nx_points, Ny_points, call_save_movie=True, fps = 3)

plot_figures(u, u_pr, xmin, xmax, ymin, ymax, Nx_points, Ny_points)
# Out:
# Warning: 300 points required, but 324 points sampled.
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.129060 s
#
# 'compile' took 1.233308 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [2.10e+02, 2.67e-01]    [2.10e+02, 2.67e-01]    [1.05e+00]
# Epoch 1: train loss improved from inf to 2.11e+02, saving model to model/model-1.ckpt ...
#
# 100       [1.19e+02, 2.58e-01]    [1.17e+02, 2.58e-01]    [1.07e+00]
# Epoch 100: train loss improved from 2.11e+02 to 1.19e+02, saving model to model/model-100.ckpt ...
#
#
# Best model at step 100:
#   train loss: 1.19e+02
#   test loss: 1.17e+02
#   test metric: [1.07e+00]
#
# 'train' took 10.604034 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 100       [1.19e+02, 2.58e-01]    [1.17e+02, 2.58e-01]    [1.07e+00]
# 200       [3.19e+01, 8.93e-01]    [1.80e+01, 8.93e-01]    [1.48e+00]
# Epoch 200: train loss improved from 1.19e+02 to 3.28e+01, saving model to model/model-200.ckpt ...
#
#
# Best model at step 200:
#   train loss: 3.28e+01
#   test loss: 1.89e+01
#   test metric: [1.48e+00]
#
# 'train' took 6.323807 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 200       [3.19e+01, 8.93e-01]    [1.80e+01, 8.93e-01]    [1.48e+00]
# 300       [8.74e+00, 1.45e+00]    [2.86e+00, 1.45e+00]    [2.05e+00]
# Epoch 300: train loss improved from 3.28e+01 to 1.02e+01, saving model to model/model-300.ckpt ...
#
#
# Best model at step 300:
#   train loss: 1.02e+01
#   test loss: 4.31e+00
#   test metric: [2.05e+00]
#
# 'train' took 7.093160 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 300       [8.74e+00, 1.45e+00]    [2.86e+00, 1.45e+00]    [2.05e+00]
# 400       [2.34e+00, 2.52e-01]    [1.38e+00, 2.52e-01]    [8.04e-01]
# Epoch 400: train loss improved from 1.02e+01 to 2.60e+00, saving model to model/model-400.ckpt ...
#
#
# Best model at step 400:
#   train loss: 2.60e+00
#   test loss: 1.63e+00
#   test metric: [8.04e-01]
#
# 'train' took 6.465243 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 400       [2.34e+00, 2.52e-01]    [1.38e+00, 2.52e-01]    [8.04e-01]
# 500       [3.02e-01, 1.21e-01]    [1.73e-01, 1.21e-01]    [4.49e-01]
# Epoch 500: train loss improved from 2.60e+00 to 4.23e-01, saving model to model/model-500.ckpt ...
#
#
# Best model at step 500:
#   train loss: 4.23e-01
#   test loss: 2.94e-01
#   test metric: [4.49e-01]
#
# 'train' took 7.259671 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 500       [3.02e-01, 1.21e-01]    [1.73e-01, 1.21e-01]    [4.49e-01]
# 600       [1.26e-01, 5.51e-02]    [8.07e-02, 5.51e-02]    [2.98e-01]
# Epoch 600: train loss improved from 4.23e-01 to 1.81e-01, saving model to model/model-600.ckpt ...
#
#
# Best model at step 600:
#   train loss: 1.81e-01
#   test loss: 1.36e-01
#   test metric: [2.98e-01]
#
# 'train' took 6.849746 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 600       [1.26e-01, 5.51e-02]    [8.07e-02, 5.51e-02]    [2.98e-01]
# 700       [7.04e-02, 2.86e-02]    [4.75e-02, 2.86e-02]    [2.12e-01]
# Epoch 700: train loss improved from 1.81e-01 to 9.90e-02, saving model to model/model-700.ckpt ...
#
#
# Best model at step 700:
#   train loss: 9.90e-02
#   test loss: 7.61e-02
#   test metric: [2.12e-01]
#
# 'train' took 7.226863 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 700       [7.04e-02, 2.86e-02]    [4.75e-02, 2.86e-02]    [2.12e-01]
# 800       [6.17e-02, 1.80e-02]    [5.48e-02, 1.80e-02]    [1.67e-01]
# Epoch 800: train loss improved from 9.90e-02 to 7.97e-02, saving model to model/model-800.ckpt ...
#
#
# Best model at step 800:
#   train loss: 7.97e-02
#   test loss: 7.28e-02
#   test metric: [1.67e-01]
#
# 'train' took 7.243306 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 800       [6.17e-02, 1.80e-02]    [5.48e-02, 1.80e-02]    [1.67e-01]
# 900       [4.61e-02, 1.31e-02]    [4.16e-02, 1.31e-02]    [1.42e-01]
# Epoch 900: train loss improved from 7.97e-02 to 5.92e-02, saving model to model/model-900.ckpt ...
#
#
# Best model at step 900:
#   train loss: 5.92e-02
#   test loss: 5.47e-02
#   test metric: [1.42e-01]
#
# 'train' took 6.818051 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 900       [4.61e-02, 1.31e-02]    [4.16e-02, 1.31e-02]    [1.42e-01]
# 1000      [2.93e-02, 1.06e-02]    [2.24e-02, 1.06e-02]    [1.28e-01]
# Epoch 1000: train loss improved from 5.92e-02 to 3.99e-02, saving model to model/model-1000.ckpt ...
#
#
# Best model at step 1000:
#   train loss: 3.99e-02
#   test loss: 3.30e-02
#   test metric: [1.28e-01]
#
# 'train' took 7.510552 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1000      [2.93e-02, 1.06e-02]    [2.24e-02, 1.06e-02]    [1.28e-01]
# 1100      [1.09e-01, 9.02e-03]    [1.12e-01, 9.02e-03]    [1.19e-01]
#
# Best model at step 1000:
#   train loss: 3.99e-02
#   test loss: 3.30e-02
#   test metric: [1.28e-01]
#
# 'train' took 5.471855 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1100      [1.09e-01, 9.02e-03]    [1.12e-01, 9.02e-03]    [1.19e-01]
# 1200      [2.17e-02, 7.89e-03]    [1.70e-02, 7.89e-03]    [1.10e-01]
# Epoch 1200: train loss improved from 3.99e-02 to 2.96e-02, saving model to model/model-1200.ckpt ...
#
#
# Best model at step 1200:
#   train loss: 2.96e-02
#   test loss: 2.48e-02
#   test metric: [1.10e-01]
#
# 'train' took 7.698922 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1200      [2.17e-02, 7.89e-03]    [1.70e-02, 7.89e-03]    [1.10e-01]
# 1300      [1.97e-01, 6.63e-03]    [2.12e-01, 6.63e-03]    [1.03e-01]
#
# Best model at step 1200:
#   train loss: 2.96e-02
#   test loss: 2.48e-02
#   test metric: [1.10e-01]
#
# 'train' took 5.671465 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1300      [1.97e-01, 6.63e-03]    [2.12e-01, 6.63e-03]    [1.03e-01]
# 1400      [1.75e-02, 6.32e-03]    [1.33e-02, 6.32e-03]    [9.85e-02]
# Epoch 1400: train loss improved from 2.96e-02 to 2.38e-02, saving model to model/model-1400.ckpt ...
#
#
# Best model at step 1400:
#   train loss: 2.38e-02
#   test loss: 1.96e-02
#   test metric: [9.85e-02]
#
# 'train' took 7.737461 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1400      [1.75e-02, 6.32e-03]    [1.33e-02, 6.32e-03]    [9.85e-02]
# 1500      [1.57e-02, 5.71e-03]    [1.18e-02, 5.71e-03]    [9.36e-02]
# Epoch 1500: train loss improved from 2.38e-02 to 2.14e-02, saving model to model/model-1500.ckpt ...
#
#
# Best model at step 1500:
#   train loss: 2.14e-02
#   test loss: 1.75e-02
#   test metric: [9.36e-02]
#
# 'train' took 7.569335 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1500      [1.57e-02, 5.71e-03]    [1.18e-02, 5.71e-03]    [9.36e-02]
# 1600      [1.51e-02, 5.31e-03]    [1.17e-02, 5.31e-03]    [9.01e-02]
# Epoch 1600: train loss improved from 2.14e-02 to 2.04e-02, saving model to model/model-1600.ckpt ...
#
#
# Best model at step 1600:
#   train loss: 2.04e-02
#   test loss: 1.71e-02
#   test metric: [9.01e-02]
#
# 'train' took 7.126624 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1600      [1.51e-02, 5.31e-03]    [1.17e-02, 5.31e-03]    [9.01e-02]
# 1700      [1.33e-02, 4.85e-03]    [9.84e-03, 4.85e-03]    [8.62e-02]
# Epoch 1700: train loss improved from 2.04e-02 to 1.82e-02, saving model to model/model-1700.ckpt ...
#
#
# Best model at step 1700:
#   train loss: 1.82e-02
#   test loss: 1.47e-02
#   test metric: [8.62e-02]
#
# 'train' took 7.891478 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1700      [1.33e-02, 4.85e-03]    [9.84e-03, 4.85e-03]    [8.62e-02]
# 1800      [1.23e-02, 4.46e-03]    [8.84e-03, 4.46e-03]    [8.25e-02]
# Epoch 1800: train loss improved from 1.82e-02 to 1.67e-02, saving model to model/model-1800.ckpt ...
#
#
# Best model at step 1800:
#   train loss: 1.67e-02
#   test loss: 1.33e-02
#   test metric: [8.25e-02]
#
# 'train' took 7.797876 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1800      [1.23e-02, 4.46e-03]    [8.84e-03, 4.46e-03]    [8.25e-02]
# 1900      [1.15e-02, 4.24e-03]    [8.39e-03, 4.24e-03]    [8.03e-02]
# Epoch 1900: train loss improved from 1.67e-02 to 1.58e-02, saving model to model/model-1900.ckpt ...
#
#
# Best model at step 1900:
#   train loss: 1.58e-02
#   test loss: 1.26e-02
#   test metric: [8.03e-02]
#
# 'train' took 7.138942 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1900      [1.15e-02, 4.24e-03]    [8.39e-03, 4.24e-03]    [8.03e-02]
# 2000      [1.07e-02, 3.92e-03]    [7.62e-03, 3.92e-03]    [7.72e-02]
# Epoch 2000: train loss improved from 1.58e-02 to 1.46e-02, saving model to model/model-2000.ckpt ...
#
#
# Best model at step 2000:
#   train loss: 1.46e-02
#   test loss: 1.15e-02
#   test metric: [7.72e-02]
#
# 'train' took 7.716144 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2000      [1.07e-02, 3.92e-03]    [7.62e-03, 3.92e-03]    [7.72e-02]
# 2100      [9.90e-03, 3.64e-03]    [6.97e-03, 3.64e-03]    [7.44e-02]
# Epoch 2100: train loss improved from 1.46e-02 to 1.35e-02, saving model to model/model-2100.ckpt ...
#
#
# Best model at step 2100:
#   train loss: 1.35e-02
#   test loss: 1.06e-02
#   test metric: [7.44e-02]
#
# 'train' took 7.511536 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2100      [9.90e-03, 3.64e-03]    [6.97e-03, 3.64e-03]    [7.44e-02]
# 2200      [1.79e-02, 3.62e-03]    [1.82e-02, 3.62e-03]    [7.43e-02]
#
# Best model at step 2100:
#   train loss: 1.35e-02
#   test loss: 1.06e-02
#   test metric: [7.44e-02]
#
# 'train' took 6.088501 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2200      [1.79e-02, 3.62e-03]    [1.82e-02, 3.62e-03]    [7.43e-02]
# 2300      [8.81e-03, 3.27e-03]    [6.13e-03, 3.27e-03]    [7.03e-02]
# Epoch 2300: train loss improved from 1.35e-02 to 1.21e-02, saving model to model/model-2300.ckpt ...
#
#
# Best model at step 2300:
#   train loss: 1.21e-02
#   test loss: 9.40e-03
#   test metric: [7.03e-02]
#
# 'train' took 7.910597 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2300      [8.81e-03, 3.27e-03]    [6.13e-03, 3.27e-03]    [7.03e-02]
# 2400      [8.24e-03, 3.06e-03]    [5.66e-03, 3.06e-03]    [6.80e-02]
# Epoch 2400: train loss improved from 1.21e-02 to 1.13e-02, saving model to model/model-2400.ckpt ...
#
#
# Best model at step 2400:
#   train loss: 1.13e-02
#   test loss: 8.72e-03
#   test metric: [6.80e-02]
#
# 'train' took 7.255705 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2400      [8.24e-03, 3.06e-03]    [5.66e-03, 3.06e-03]    [6.80e-02]
# 2500      [6.24e-01, 2.43e-03]    [6.95e-01, 2.43e-03]    [7.49e-02]
#
# Best model at step 2400:
#   train loss: 1.13e-02
#   test loss: 8.72e-03
#   test metric: [6.80e-02]
#
# 'train' took 8.811381 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2500      [6.24e-01, 2.43e-03]    [6.95e-01, 2.43e-03]    [7.49e-02]
#
# Best model at step 2400:
#   train loss: 1.13e-02
#   test loss: 8.72e-03
#   test metric: [6.80e-02]
#
# 'train' took 7.168762 s
#
# Movie saved as movie_2_5.gif
# Saving loss history to /content/loss.dat ...
# Saving training data to /content/train.dat ...
# Saving test data to /content/test.dat ...
# Restoring model from model/model-2400.ckpt ...
#
# eps_l2 =  0.044085354
# eps_c =  0.15908077
# residual_l2 =  0.0060460805
# residual_c =  0.8088024

# %%
#frequencies of solution
a = 5
b = 5
#domain boundaries
xmax = np.pi
ymax = np.pi
xmin = 0
ymin = 0
#number of iterations for training
N_iter = 10000
Nx_points = 100
Ny_points = 100

u, u_pr, training_frames = predict_u_with_PINN(a, b, xmin, ymin, xmax, ymax, N_iter, Nx_points, Ny_points, call_save_movie=True, fps = 3)

plot_figures(u, u_pr, xmin, xmax, ymin, ymax, Nx_points, Ny_points)
# Out:
# Warning: 300 points required, but 324 points sampled.
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.093297 s
#
# 'compile' took 0.756809 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [6.27e+02, 6.56e-01]    [6.23e+02, 6.56e-01]    [1.52e+00]
# Epoch 1: train loss improved from inf to 6.28e+02, saving model to model/model-1.ckpt ...
#
# 100       [4.26e+02, 1.01e+00]    [4.15e+02, 1.01e+00]    [1.90e+00]
# Epoch 100: train loss improved from 6.28e+02 to 4.27e+02, saving model to model/model-100.ckpt ...
#
#
# Best model at step 100:
#   train loss: 4.27e+02
#   test loss: 4.16e+02
#   test metric: [1.90e+00]
#
# 'train' took 4.813417 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 100       [4.26e+02, 1.01e+00]    [4.15e+02, 1.01e+00]    [1.90e+00]
# 200       [3.42e+02, 1.33e+00]    [3.41e+02, 1.33e+00]    [2.18e+00]
# Epoch 200: train loss improved from 4.27e+02 to 3.43e+02, saving model to model/model-200.ckpt ...
#
#
# Best model at step 200:
#   train loss: 3.43e+02
#   test loss: 3.43e+02
#   test metric: [2.18e+00]
#
# 'train' took 1.342734 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 200       [3.42e+02, 1.33e+00]    [3.41e+02, 1.33e+00]    [2.18e+00]
# 300       [3.01e+02, 1.95e+00]    [3.10e+02, 1.95e+00]    [2.01e+00]
# Epoch 300: train loss improved from 3.43e+02 to 3.03e+02, saving model to model/model-300.ckpt ...
#
#
# Best model at step 300:
#   train loss: 3.03e+02
#   test loss: 3.12e+02
#   test metric: [2.01e+00]
#
# 'train' took 1.331109 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 300       [3.01e+02, 1.95e+00]    [3.10e+02, 1.95e+00]    [2.01e+00]
# 400       [2.59e+02, 1.60e+00]    [2.69e+02, 1.60e+00]    [2.03e+00]
# Epoch 400: train loss improved from 3.03e+02 to 2.60e+02, saving model to model/model-400.ckpt ...
#
#
# Best model at step 400:
#   train loss: 2.60e+02
#   test loss: 2.71e+02
#   test metric: [2.03e+00]
#
# 'train' took 1.345314 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 400       [2.59e+02, 1.60e+00]    [2.69e+02, 1.60e+00]    [2.03e+00]
# 500       [1.62e+02, 6.67e-01]    [1.74e+02, 6.67e-01]    [1.86e+00]
# Epoch 500: train loss improved from 2.60e+02 to 1.63e+02, saving model to model/model-500.ckpt ...
#
#
# Best model at step 500:
#   train loss: 1.63e+02
#   test loss: 1.75e+02
#   test metric: [1.86e+00]
#
# 'train' took 1.331491 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 500       [1.62e+02, 6.67e-01]    [1.74e+02, 6.67e-01]    [1.86e+00]
# 600       [4.45e+01, 5.17e-01]    [4.78e+01, 5.17e-01]    [1.10e+00]
# Epoch 600: train loss improved from 1.63e+02 to 4.51e+01, saving model to model/model-600.ckpt ...
#
#
# Best model at step 600:
#   train loss: 4.51e+01
#   test loss: 4.83e+01
#   test metric: [1.10e+00]
#
# 'train' took 1.364581 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 600       [4.45e+01, 5.17e-01]    [4.78e+01, 5.17e-01]    [1.10e+00]
# 700       [2.34e+00, 4.06e-01]    [2.03e+00, 4.06e-01]    [8.66e-01]
# Epoch 700: train loss improved from 4.51e+01 to 2.75e+00, saving model to model/model-700.ckpt ...
#
#
# Best model at step 700:
#   train loss: 2.75e+00
#   test loss: 2.44e+00
#   test metric: [8.66e-01]
#
# 'train' took 1.390996 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 700       [2.34e+00, 4.06e-01]    [2.03e+00, 4.06e-01]    [8.66e-01]
# 800       [1.04e+00, 2.39e-01]    [8.04e-01, 2.39e-01]    [6.25e-01]
# Epoch 800: train loss improved from 2.75e+00 to 1.28e+00, saving model to model/model-800.ckpt ...
#
#
# Best model at step 800:
#   train loss: 1.28e+00
#   test loss: 1.04e+00
#   test metric: [6.25e-01]
#
# 'train' took 2.122324 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 800       [1.04e+00, 2.39e-01]    [8.04e-01, 2.39e-01]    [6.25e-01]
# 900       [7.29e-01, 1.80e-01]    [5.44e-01, 1.80e-01]    [5.36e-01]
# Epoch 900: train loss improved from 1.28e+00 to 9.09e-01, saving model to model/model-900.ckpt ...
#
#
# Best model at step 900:
#   train loss: 9.09e-01
#   test loss: 7.24e-01
#   test metric: [5.36e-01]
#
# 'train' took 1.414969 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 900       [7.29e-01, 1.80e-01]    [5.44e-01, 1.80e-01]    [5.36e-01]
# 1000      [5.36e-01, 1.44e-01]    [3.85e-01, 1.44e-01]    [4.76e-01]
# Epoch 1000: train loss improved from 9.09e-01 to 6.80e-01, saving model to model/model-1000.ckpt ...
#
#
# Best model at step 1000:
#   train loss: 6.80e-01
#   test loss: 5.29e-01
#   test metric: [4.76e-01]
#
# 'train' took 1.423501 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1000      [5.36e-01, 1.44e-01]    [3.85e-01, 1.44e-01]    [4.76e-01]
# 1100      [4.20e-01, 1.19e-01]    [2.91e-01, 1.19e-01]    [4.28e-01]
# Epoch 1100: train loss improved from 6.80e-01 to 5.38e-01, saving model to model/model-1100.ckpt ...
#
#
# Best model at step 1100:
#   train loss: 5.38e-01
#   test loss: 4.09e-01
#   test metric: [4.28e-01]
#
# 'train' took 1.439503 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1100      [4.20e-01, 1.19e-01]    [2.91e-01, 1.19e-01]    [4.28e-01]
# 1200      [3.30e-01, 9.89e-02]    [2.23e-01, 9.89e-02]    [3.89e-01]
# Epoch 1200: train loss improved from 5.38e-01 to 4.29e-01, saving model to model/model-1200.ckpt ...
#
#
# Best model at step 1200:
#   train loss: 4.29e-01
#   test loss: 3.22e-01
#   test metric: [3.89e-01]
#
# 'train' took 1.517107 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1200      [3.30e-01, 9.89e-02]    [2.23e-01, 9.89e-02]    [3.89e-01]
# 1300      [2.69e-01, 8.44e-02]    [1.78e-01, 8.44e-02]    [3.58e-01]
# Epoch 1300: train loss improved from 4.29e-01 to 3.54e-01, saving model to model/model-1300.ckpt ...
#
#
# Best model at step 1300:
#   train loss: 3.54e-01
#   test loss: 2.63e-01
#   test metric: [3.58e-01]
#
# 'train' took 1.462614 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1300      [2.69e-01, 8.44e-02]    [1.78e-01, 8.44e-02]    [3.58e-01]
# 1400      [3.36e+00, 7.44e-02]    [3.65e+00, 7.44e-02]    [3.41e-01]
#
# Best model at step 1300:
#   train loss: 3.54e-01
#   test loss: 2.63e-01
#   test metric: [3.58e-01]
#
# 'train' took 1.199997 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1400      [3.36e+00, 7.44e-02]    [3.65e+00, 7.44e-02]    [3.41e-01]
# 1500      [1.84e-01, 6.46e-02]    [1.21e-01, 6.46e-02]    [3.13e-01]
# Epoch 1500: train loss improved from 3.54e-01 to 2.48e-01, saving model to model/model-1500.ckpt ...
#
#
# Best model at step 1500:
#   train loss: 2.48e-01
#   test loss: 1.85e-01
#   test metric: [3.13e-01]
#
# 'train' took 1.482227 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1500      [1.84e-01, 6.46e-02]    [1.21e-01, 6.46e-02]    [3.13e-01]
# 1600      [1.29e+00, 6.22e-02]    [1.06e+00, 6.22e-02]    [3.07e-01]
#
# Best model at step 1500:
#   train loss: 2.48e-01
#   test loss: 1.85e-01
#   test metric: [3.13e-01]
#
# 'train' took 1.924598 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1600      [1.29e+00, 6.22e-02]    [1.06e+00, 6.22e-02]    [3.07e-01]
# 1700      [1.30e-01, 5.06e-02]    [8.72e-02, 5.06e-02]    [2.77e-01]
# Epoch 1700: train loss improved from 2.48e-01 to 1.81e-01, saving model to model/model-1700.ckpt ...
#
#
# Best model at step 1700:
#   train loss: 1.81e-01
#   test loss: 1.38e-01
#   test metric: [2.77e-01]
#
# 'train' took 1.572785 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1700      [1.30e-01, 5.06e-02]    [8.72e-02, 5.06e-02]    [2.77e-01]
# 1800      [1.12e-01, 4.48e-02]    [7.78e-02, 4.48e-02]    [2.60e-01]
# Epoch 1800: train loss improved from 1.81e-01 to 1.57e-01, saving model to model/model-1800.ckpt ...
#
#
# Best model at step 1800:
#   train loss: 1.57e-01
#   test loss: 1.23e-01
#   test metric: [2.60e-01]
#
# 'train' took 1.501418 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1800      [1.12e-01, 4.48e-02]    [7.78e-02, 4.48e-02]    [2.60e-01]
# 1900      [9.70e-02, 4.01e-02]    [6.82e-02, 4.01e-02]    [2.46e-01]
# Epoch 1900: train loss improved from 1.57e-01 to 1.37e-01, saving model to model/model-1900.ckpt ...
#
#
# Best model at step 1900:
#   train loss: 1.37e-01
#   test loss: 1.08e-01
#   test metric: [2.46e-01]
#
# 'train' took 1.531841 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1900      [9.70e-02, 4.01e-02]    [6.82e-02, 4.01e-02]    [2.46e-01]
# 2000      [4.54e-01, 3.40e-02]    [3.72e-01, 3.40e-02]    [2.27e-01]
#
# Best model at step 1900:
#   train loss: 1.37e-01
#   test loss: 1.08e-01
#   test metric: [2.46e-01]
#
# 'train' took 1.260089 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2000      [4.54e-01, 3.40e-02]    [3.72e-01, 3.40e-02]    [2.27e-01]
# 2100      [7.63e-02, 3.18e-02]    [5.52e-02, 3.18e-02]    [2.19e-01]
# Epoch 2100: train loss improved from 1.37e-01 to 1.08e-01, saving model to model/model-2100.ckpt ...
#
#
# Best model at step 2100:
#   train loss: 1.08e-01
#   test loss: 8.70e-02
#   test metric: [2.19e-01]
#
# 'train' took 1.536819 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2100      [7.63e-02, 3.18e-02]    [5.52e-02, 3.18e-02]    [2.19e-01]
# 2200      [1.26e-01, 2.93e-02]    [1.14e-01, 2.93e-02]    [2.10e-01]
#
# Best model at step 2100:
#   train loss: 1.08e-01
#   test loss: 8.70e-02
#   test metric: [2.19e-01]
#
# 'train' took 1.285424 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2200      [1.26e-01, 2.93e-02]    [1.14e-01, 2.93e-02]    [2.10e-01]
# 2300      [1.27e-01, 2.52e-02]    [1.06e-01, 2.52e-02]    [1.94e-01]
#
# Best model at step 2100:
#   train loss: 1.08e-01
#   test loss: 8.70e-02
#   test metric: [2.19e-01]
#
# 'train' took 1.282842 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2300      [1.27e-01, 2.52e-02]    [1.06e-01, 2.52e-02]    [1.94e-01]
# 2400      [2.21e-01, 2.22e-02]    [1.87e-01, 2.22e-02]    [1.83e-01]
#
# Best model at step 2100:
#   train loss: 1.08e-01
#   test loss: 8.70e-02
#   test metric: [2.19e-01]
#
# 'train' took 1.928196 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2400      [2.21e-01, 2.22e-02]    [1.87e-01, 2.22e-02]    [1.83e-01]
# 2500      [1.51e-01, 2.15e-02]    [1.34e-01, 2.15e-02]    [1.79e-01]
#
# Best model at step 2100:
#   train loss: 1.08e-01
#   test loss: 8.70e-02
#   test metric: [2.19e-01]
#
# 'train' took 1.440814 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2500      [1.51e-01, 2.15e-02]    [1.34e-01, 2.15e-02]    [1.79e-01]
# 2600      [4.65e-02, 1.99e-02]    [3.47e-02, 1.99e-02]    [1.72e-01]
# Epoch 2600: train loss improved from 1.08e-01 to 6.64e-02, saving model to model/model-2600.ckpt ...
#
#
# Best model at step 2600:
#   train loss: 6.64e-02
#   test loss: 5.47e-02
#   test metric: [1.72e-01]
#
# 'train' took 1.581759 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2600      [4.65e-02, 1.99e-02]    [3.47e-02, 1.99e-02]    [1.72e-01]
# 2700      [5.60e-02, 1.90e-02]    [4.63e-02, 1.90e-02]    [1.68e-01]
#
# Best model at step 2600:
#   train loss: 6.64e-02
#   test loss: 5.47e-02
#   test metric: [1.72e-01]
#
# 'train' took 1.280444 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2700      [5.60e-02, 1.90e-02]    [4.63e-02, 1.90e-02]    [1.68e-01]
# 2800      [2.72e-01, 1.95e-02]    [2.34e-01, 1.95e-02]    [1.71e-01]
#
# Best model at step 2600:
#   train loss: 6.64e-02
#   test loss: 5.47e-02
#   test metric: [1.72e-01]
#
# 'train' took 1.302072 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2800      [2.72e-01, 1.95e-02]    [2.34e-01, 1.95e-02]    [1.71e-01]
# 2900      [6.95e-02, 1.63e-02]    [6.20e-02, 1.63e-02]    [1.56e-01]
#
# Best model at step 2600:
#   train loss: 6.64e-02
#   test loss: 5.47e-02
#   test metric: [1.72e-01]
#
# 'train' took 1.304340 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2900      [6.95e-02, 1.63e-02]    [6.20e-02, 1.63e-02]    [1.56e-01]
# 3000      [1.51e-01, 1.67e-02]    [1.25e-01, 1.67e-02]    [1.57e-01]
#
# Best model at step 2600:
#   train loss: 6.64e-02
#   test loss: 5.47e-02
#   test metric: [1.72e-01]
#
# 'train' took 1.268643 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3000      [1.51e-01, 1.67e-02]    [1.25e-01, 1.67e-02]    [1.57e-01]
# 3100      [9.34e-02, 1.55e-02]    [8.03e-02, 1.55e-02]    [1.51e-01]
#
# Best model at step 2600:
#   train loss: 6.64e-02
#   test loss: 5.47e-02
#   test metric: [1.72e-01]
#
# 'train' took 1.330330 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3100      [9.34e-02, 1.55e-02]    [8.03e-02, 1.55e-02]    [1.51e-01]
# 3200      [1.49e-01, 1.27e-02]    [1.25e-01, 1.27e-02]    [1.38e-01]
#
# Best model at step 2600:
#   train loss: 6.64e-02
#   test loss: 5.47e-02
#   test metric: [1.72e-01]
#
# 'train' took 1.506715 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3200      [1.49e-01, 1.27e-02]    [1.25e-01, 1.27e-02]    [1.38e-01]
# 3300      [1.50e-01, 1.21e-02]    [1.46e-01, 1.21e-02]    [1.34e-01]
#
# Best model at step 2600:
#   train loss: 6.64e-02
#   test loss: 5.47e-02
#   test metric: [1.72e-01]
#
# 'train' took 1.750539 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3300      [1.50e-01, 1.21e-02]    [1.46e-01, 1.21e-02]    [1.34e-01]
# 3400      [5.55e-02, 1.19e-02]    [4.30e-02, 1.19e-02]    [1.33e-01]
#
# Best model at step 2600:
#   train loss: 6.64e-02
#   test loss: 5.47e-02
#   test metric: [1.72e-01]
#
# 'train' took 1.348764 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3400      [5.55e-02, 1.19e-02]    [4.30e-02, 1.19e-02]    [1.33e-01]
# 3500      [1.30e-01, 1.10e-02]    [1.00e-01, 1.10e-02]    [1.27e-01]
#
# Best model at step 2600:
#   train loss: 6.64e-02
#   test loss: 5.47e-02
#   test metric: [1.72e-01]
#
# 'train' took 2.292965 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3500      [1.30e-01, 1.10e-02]    [1.00e-01, 1.10e-02]    [1.27e-01]
# 3600      [2.87e-02, 1.16e-02]    [2.26e-02, 1.16e-02]    [1.31e-01]
# Epoch 3600: train loss improved from 6.64e-02 to 4.04e-02, saving model to model/model-3600.ckpt ...
#
#
# Best model at step 3600:
#   train loss: 4.04e-02
#   test loss: 3.42e-02
#   test metric: [1.31e-01]
#
# 'train' took 1.705130 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3600      [2.87e-02, 1.16e-02]    [2.26e-02, 1.16e-02]    [1.31e-01]
# 3700      [3.57e-02, 1.07e-02]    [2.92e-02, 1.07e-02]    [1.25e-01]
#
# Best model at step 3600:
#   train loss: 4.04e-02
#   test loss: 3.42e-02
#   test metric: [1.31e-01]
#
# 'train' took 1.352739 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3700      [3.57e-02, 1.07e-02]    [2.92e-02, 1.07e-02]    [1.25e-01]
# 3800      [2.45e-02, 1.02e-02]    [1.89e-02, 1.02e-02]    [1.22e-01]
# Epoch 3800: train loss improved from 4.04e-02 to 3.47e-02, saving model to model/model-3800.ckpt ...
#
#
# Best model at step 3800:
#   train loss: 3.47e-02
#   test loss: 2.91e-02
#   test metric: [1.22e-01]
#
# 'train' took 1.691840 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3800      [2.45e-02, 1.02e-02]    [1.89e-02, 1.02e-02]    [1.22e-01]
# 3900      [3.81e-01, 9.29e-03]    [3.29e-01, 9.29e-03]    [1.19e-01]
#
# Best model at step 3800:
#   train loss: 3.47e-02
#   test loss: 2.91e-02
#   test metric: [1.22e-01]
#
# 'train' took 1.483400 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3900      [3.81e-01, 9.29e-03]    [3.29e-01, 9.29e-03]    [1.19e-01]
# 4000      [3.28e-02, 9.27e-03]    [2.63e-02, 9.27e-03]    [1.17e-01]
#
# Best model at step 3800:
#   train loss: 3.47e-02
#   test loss: 2.91e-02
#   test metric: [1.22e-01]
#
# 'train' took 1.950011 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4000      [3.28e-02, 9.27e-03]    [2.63e-02, 9.27e-03]    [1.17e-01]
# 4100      [3.18e-01, 7.96e-03]    [2.80e-01, 7.96e-03]    [1.10e-01]
#
# Best model at step 3800:
#   train loss: 3.47e-02
#   test loss: 2.91e-02
#   test metric: [1.22e-01]
#
# 'train' took 1.361251 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4100      [3.18e-01, 7.96e-03]    [2.80e-01, 7.96e-03]    [1.10e-01]
# 4200      [6.40e-02, 8.91e-03]    [6.10e-02, 8.91e-03]    [1.14e-01]
#
# Best model at step 3800:
#   train loss: 3.47e-02
#   test loss: 2.91e-02
#   test metric: [1.22e-01]
#
# 'train' took 1.392448 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4200      [6.40e-02, 8.91e-03]    [6.10e-02, 8.91e-03]    [1.14e-01]
# 4300      [2.03e-02, 8.71e-03]    [1.69e-02, 8.71e-03]    [1.13e-01]
# Epoch 4300: train loss improved from 3.47e-02 to 2.90e-02, saving model to model/model-4300.ckpt ...
#
#
# Best model at step 4300:
#   train loss: 2.90e-02
#   test loss: 2.56e-02
#   test metric: [1.13e-01]
#
# 'train' took 1.760745 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4300      [2.03e-02, 8.71e-03]    [1.69e-02, 8.71e-03]    [1.13e-01]
# 4400      [4.59e-02, 7.83e-03]    [3.63e-02, 7.83e-03]    [1.07e-01]
#
# Best model at step 4300:
#   train loss: 2.90e-02
#   test loss: 2.56e-02
#   test metric: [1.13e-01]
#
# 'train' took 1.424499 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4400      [4.59e-02, 7.83e-03]    [3.63e-02, 7.83e-03]    [1.07e-01]
# 4500      [6.50e-01, 1.04e-02]    [5.71e-01, 1.04e-02]    [1.25e-01]
#
# Best model at step 4300:
#   train loss: 2.90e-02
#   test loss: 2.56e-02
#   test metric: [1.13e-01]
#
# 'train' took 1.443660 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4500      [6.50e-01, 1.04e-02]    [5.71e-01, 1.04e-02]    [1.25e-01]
# 4600      [2.20e-01, 8.59e-03]    [2.34e-01, 8.59e-03]    [1.13e-01]
#
# Best model at step 4300:
#   train loss: 2.90e-02
#   test loss: 2.56e-02
#   test metric: [1.13e-01]
#
# 'train' took 1.396609 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4600      [2.20e-01, 8.59e-03]    [2.34e-01, 8.59e-03]    [1.13e-01]
# 4700      [3.76e-02, 7.10e-03]    [3.29e-02, 7.10e-03]    [1.02e-01]
#
# Best model at step 4300:
#   train loss: 2.90e-02
#   test loss: 2.56e-02
#   test metric: [1.13e-01]
#
# 'train' took 1.697252 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4700      [3.76e-02, 7.10e-03]    [3.29e-02, 7.10e-03]    [1.02e-01]
# 4800      [1.53e-02, 7.21e-03]    [1.26e-02, 7.21e-03]    [1.03e-01]
# Epoch 4800: train loss improved from 2.90e-02 to 2.25e-02, saving model to model/model-4800.ckpt ...
#
#
# Best model at step 4800:
#   train loss: 2.25e-02
#   test loss: 1.98e-02
#   test metric: [1.03e-01]
#
# 'train' took 2.210845 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4800      [1.53e-02, 7.21e-03]    [1.26e-02, 7.21e-03]    [1.03e-01]
# 4900      [1.73e-02, 7.13e-03]    [1.48e-02, 7.13e-03]    [1.02e-01]
#
# Best model at step 4800:
#   train loss: 2.25e-02
#   test loss: 1.98e-02
#   test metric: [1.03e-01]
#
# 'train' took 1.458031 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4900      [1.73e-02, 7.13e-03]    [1.48e-02, 7.13e-03]    [1.02e-01]
# 5000      [2.28e-02, 6.64e-03]    [1.77e-02, 6.64e-03]    [9.86e-02]
#
# Best model at step 4800:
#   train loss: 2.25e-02
#   test loss: 1.98e-02
#   test metric: [1.03e-01]
#
# 'train' took 1.460735 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [2.28e-02, 6.64e-03]    [1.77e-02, 6.64e-03]    [9.86e-02]
#
# Best model at step 4800:
#   train loss: 2.25e-02
#   test loss: 1.98e-02
#   test metric: [1.03e-01]
#
# 'train' took 1.231377 s
#
# Movie saved as movie_5_5.gif
# Saving loss history to /content/loss.dat ...
# Saving training data to /content/train.dat ...
# Saving test data to /content/test.dat ...
# Restoring model from model/model-4800.ckpt ...
#
# eps_l2 =  0.06561979
# eps_c =  0.19709046
# residual_l2 =  0.005037504
# residual_c =  1.3357495

# %%
#frequencies of solution
a = 5
b = 8
#domain boundaries
xmax = np.pi
ymax = np.pi
xmin = 0
ymin = 0
#number of iterations for training
N_iter = 10000
Nx_points = 100
Ny_points = 100

u, u_pr, training_frames = predict_u_with_PINN(a, b, xmin, ymin, xmax, ymax, N_iter, Nx_points, Ny_points, call_save_movie=True, fps = 3)

plot_figures(u, u_pr, xmin, xmax, ymin, ymax, Nx_points, Ny_points)
# Out:
# Warning: 300 points required, but 324 points sampled.
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.071806 s
#
# 'compile' took 0.909034 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [1.99e+03, 5.48e-01]    [1.97e+03, 5.48e-01]    [1.48e+00]
# Epoch 1: train loss improved from inf to 1.99e+03, saving model to model/model-1.ckpt ...
#
# 100       [1.55e+03, 7.22e-01]    [1.48e+03, 7.22e-01]    [1.52e+00]
# Epoch 100: train loss improved from 1.99e+03 to 1.55e+03, saving model to model/model-100.ckpt ...
#
#
# Best model at step 100:
#   train loss: 1.55e+03
#   test loss: 1.48e+03
#   test metric: [1.52e+00]
#
# 'train' took 3.357763 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 100       [1.55e+03, 7.22e-01]    [1.48e+03, 7.22e-01]    [1.52e+00]
# 200       [1.21e+03, 1.02e+00]    [1.17e+03, 1.02e+00]    [1.84e+00]
# Epoch 200: train loss improved from 1.55e+03 to 1.21e+03, saving model to model/model-200.ckpt ...
#
#
# Best model at step 200:
#   train loss: 1.21e+03
#   test loss: 1.17e+03
#   test metric: [1.84e+00]
#
# 'train' took 0.455439 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 200       [1.21e+03, 1.02e+00]    [1.17e+03, 1.02e+00]    [1.84e+00]
# 300       [9.82e+02, 2.33e+00]    [9.67e+02, 2.33e+00]    [3.10e+00]
# Epoch 300: train loss improved from 1.21e+03 to 9.84e+02, saving model to model/model-300.ckpt ...
#
#
# Best model at step 300:
#   train loss: 9.84e+02
#   test loss: 9.69e+02
#   test metric: [3.10e+00]
#
# 'train' took 0.439064 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 300       [9.82e+02, 2.33e+00]    [9.67e+02, 2.33e+00]    [3.10e+00]
# 400       [8.69e+02, 3.19e+00]    [8.71e+02, 3.19e+00]    [3.00e+00]
# Epoch 400: train loss improved from 9.84e+02 to 8.72e+02, saving model to model/model-400.ckpt ...
#
#
# Best model at step 400:
#   train loss: 8.72e+02
#   test loss: 8.75e+02
#   test metric: [3.00e+00]
#
# 'train' took 0.442475 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 400       [8.69e+02, 3.19e+00]    [8.71e+02, 3.19e+00]    [3.00e+00]
# 500       [7.23e+02, 3.95e-01]    [7.31e+02, 3.95e-01]    [1.10e+00]
# Epoch 500: train loss improved from 8.72e+02 to 7.23e+02, saving model to model/model-500.ckpt ...
#
#
# Best model at step 500:
#   train loss: 7.23e+02
#   test loss: 7.32e+02
#   test metric: [1.10e+00]
#
# 'train' took 0.453003 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 500       [7.23e+02, 3.95e-01]    [7.31e+02, 3.95e-01]    [1.10e+00]
# 600       [5.62e+02, 8.89e-01]    [5.80e+02, 8.89e-01]    [1.88e+00]
# Epoch 600: train loss improved from 7.23e+02 to 5.62e+02, saving model to model/model-600.ckpt ...
#
#
# Best model at step 600:
#   train loss: 5.62e+02
#   test loss: 5.81e+02
#   test metric: [1.88e+00]
#
# 'train' took 0.452056 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 600       [5.62e+02, 8.89e-01]    [5.80e+02, 8.89e-01]    [1.88e+00]
# 700       [3.04e+02, 1.42e+00]    [2.88e+02, 1.42e+00]    [1.84e+00]
# Epoch 700: train loss improved from 5.62e+02 to 3.05e+02, saving model to model/model-700.ckpt ...
#
#
# Best model at step 700:
#   train loss: 3.05e+02
#   test loss: 2.90e+02
#   test metric: [1.84e+00]
#
# 'train' took 0.460251 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 700       [3.04e+02, 1.42e+00]    [2.88e+02, 1.42e+00]    [1.84e+00]
# 800       [6.76e+01, 2.24e+00]    [4.48e+01, 2.24e+00]    [2.27e+00]
# Epoch 800: train loss improved from 3.05e+02 to 6.98e+01, saving model to model/model-800.ckpt ...
#
#
# Best model at step 800:
#   train loss: 6.98e+01
#   test loss: 4.71e+01
#   test metric: [2.27e+00]
#
# 'train' took 0.462247 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 800       [6.76e+01, 2.24e+00]    [4.48e+01, 2.24e+00]    [2.27e+00]
# 900       [2.82e+01, 1.82e+00]    [2.44e+01, 1.82e+00]    [1.87e+00]
# Epoch 900: train loss improved from 6.98e+01 to 3.00e+01, saving model to model/model-900.ckpt ...
#
#
# Best model at step 900:
#   train loss: 3.00e+01
#   test loss: 2.62e+01
#   test metric: [1.87e+00]
#
# 'train' took 0.467896 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 900       [2.82e+01, 1.82e+00]    [2.44e+01, 1.82e+00]    [1.87e+00]
# 1000      [8.39e+00, 1.32e+00]    [6.33e+00, 1.32e+00]    [1.58e+00]
# Epoch 1000: train loss improved from 3.00e+01 to 9.72e+00, saving model to model/model-1000.ckpt ...
#
#
# Best model at step 1000:
#   train loss: 9.72e+00
#   test loss: 7.65e+00
#   test metric: [1.58e+00]
#
# 'train' took 0.481924 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1000      [8.39e+00, 1.32e+00]    [6.33e+00, 1.32e+00]    [1.58e+00]
# 1100      [2.92e+00, 6.20e-01]    [1.60e+00, 6.20e-01]    [1.06e+00]
# Epoch 1100: train loss improved from 9.72e+00 to 3.54e+00, saving model to model/model-1100.ckpt ...
#
#
# Best model at step 1100:
#   train loss: 3.54e+00
#   test loss: 2.21e+00
#   test metric: [1.06e+00]
#
# 'train' took 0.584539 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1100      [2.92e+00, 6.20e-01]    [1.60e+00, 6.20e-01]    [1.06e+00]
# 1200      [3.90e+00, 3.62e-01]    [3.14e+00, 3.62e-01]    [8.00e-01]
#
# Best model at step 1100:
#   train loss: 3.54e+00
#   test loss: 2.21e+00
#   test metric: [1.06e+00]
#
# 'train' took 0.556440 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1200      [3.90e+00, 3.62e-01]    [3.14e+00, 3.62e-01]    [8.00e-01]
# 1300      [1.48e+00, 2.59e-01]    [6.89e-01, 2.59e-01]    [6.68e-01]
# Epoch 1300: train loss improved from 3.54e+00 to 1.74e+00, saving model to model/model-1300.ckpt ...
#
#
# Best model at step 1300:
#   train loss: 1.74e+00
#   test loss: 9.48e-01
#   test metric: [6.68e-01]
#
# 'train' took 0.678360 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1300      [1.48e+00, 2.59e-01]    [6.89e-01, 2.59e-01]    [6.68e-01]
# 1400      [1.25e+00, 2.04e-01]    [5.94e-01, 2.04e-01]    [5.85e-01]
# Epoch 1400: train loss improved from 1.74e+00 to 1.46e+00, saving model to model/model-1400.ckpt ...
#
#
# Best model at step 1400:
#   train loss: 1.46e+00
#   test loss: 7.98e-01
#   test metric: [5.85e-01]
#
# 'train' took 0.635356 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1400      [1.25e+00, 2.04e-01]    [5.94e-01, 2.04e-01]    [5.85e-01]
# 1500      [1.07e+00, 1.72e-01]    [4.89e-01, 1.72e-01]    [5.31e-01]
# Epoch 1500: train loss improved from 1.46e+00 to 1.24e+00, saving model to model/model-1500.ckpt ...
#
#
# Best model at step 1500:
#   train loss: 1.24e+00
#   test loss: 6.60e-01
#   test metric: [5.31e-01]
#
# 'train' took 0.518595 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1500      [1.07e+00, 1.72e-01]    [4.89e-01, 1.72e-01]    [5.31e-01]
# 1600      [9.39e-01, 1.52e-01]    [4.33e-01, 1.52e-01]    [4.95e-01]
# Epoch 1600: train loss improved from 1.24e+00 to 1.09e+00, saving model to model/model-1600.ckpt ...
#
#
# Best model at step 1600:
#   train loss: 1.09e+00
#   test loss: 5.85e-01
#   test metric: [4.95e-01]
#
# 'train' took 0.501413 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1600      [9.39e-01, 1.52e-01]    [4.33e-01, 1.52e-01]    [4.95e-01]
# 1700      [2.12e+00, 1.37e-01]    [1.97e+00, 1.37e-01]    [4.66e-01]
#
# Best model at step 1600:
#   train loss: 1.09e+00
#   test loss: 5.85e-01
#   test metric: [4.95e-01]
#
# 'train' took 0.463273 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1700      [2.12e+00, 1.37e-01]    [1.97e+00, 1.37e-01]    [4.66e-01]
# 1800      [7.50e-01, 1.31e-01]    [3.51e-01, 1.31e-01]    [4.51e-01]
# Epoch 1800: train loss improved from 1.09e+00 to 8.81e-01, saving model to model/model-1800.ckpt ...
#
#
# Best model at step 1800:
#   train loss: 8.81e-01
#   test loss: 4.82e-01
#   test metric: [4.51e-01]
#
# 'train' took 0.516072 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1800      [7.50e-01, 1.31e-01]    [3.51e-01, 1.31e-01]    [4.51e-01]
# 1900      [9.02e-01, 1.23e-01]    [5.66e-01, 1.23e-01]    [4.35e-01]
#
# Best model at step 1800:
#   train loss: 8.81e-01
#   test loss: 4.82e-01
#   test metric: [4.51e-01]
#
# 'train' took 0.472599 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1900      [9.02e-01, 1.23e-01]    [5.66e-01, 1.23e-01]    [4.35e-01]
# 2000      [6.19e-01, 1.19e-01]    [2.97e-01, 1.19e-01]    [4.27e-01]
# Epoch 2000: train loss improved from 8.81e-01 to 7.38e-01, saving model to model/model-2000.ckpt ...
#
#
# Best model at step 2000:
#   train loss: 7.38e-01
#   test loss: 4.16e-01
#   test metric: [4.27e-01]
#
# 'train' took 0.520103 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2000      [6.19e-01, 1.19e-01]    [2.97e-01, 1.19e-01]    [4.27e-01]
# 2100      [5.94e-01, 1.16e-01]    [3.11e-01, 1.16e-01]    [4.18e-01]
# Epoch 2100: train loss improved from 7.38e-01 to 7.09e-01, saving model to model/model-2100.ckpt ...
#
#
# Best model at step 2100:
#   train loss: 7.09e-01
#   test loss: 4.27e-01
#   test metric: [4.18e-01]
#
# 'train' took 0.537695 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2100      [5.94e-01, 1.16e-01]    [3.11e-01, 1.16e-01]    [4.18e-01]
# 2200      [5.28e-01, 1.13e-01]    [2.58e-01, 1.13e-01]    [4.12e-01]
# Epoch 2200: train loss improved from 7.09e-01 to 6.40e-01, saving model to model/model-2200.ckpt ...
#
#
# Best model at step 2200:
#   train loss: 6.40e-01
#   test loss: 3.70e-01
#   test metric: [4.12e-01]
#
# 'train' took 0.545480 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2200      [5.28e-01, 1.13e-01]    [2.58e-01, 1.13e-01]    [4.12e-01]
# 2300      [4.96e-01, 1.10e-01]    [2.46e-01, 1.10e-01]    [4.06e-01]
# Epoch 2300: train loss improved from 6.40e-01 to 6.05e-01, saving model to model/model-2300.ckpt ...
#
#
# Best model at step 2300:
#   train loss: 6.05e-01
#   test loss: 3.55e-01
#   test metric: [4.06e-01]
#
# 'train' took 0.568249 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2300      [4.96e-01, 1.10e-01]    [2.46e-01, 1.10e-01]    [4.06e-01]
# 2400      [1.59e+00, 1.07e-01]    [1.36e+00, 1.07e-01]    [3.99e-01]
#
# Best model at step 2300:
#   train loss: 6.05e-01
#   test loss: 3.55e-01
#   test metric: [4.06e-01]
#
# 'train' took 0.486462 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2400      [1.59e+00, 1.07e-01]    [1.36e+00, 1.07e-01]    [3.99e-01]
# 2500      [4.54e-01, 1.05e-01]    [2.57e-01, 1.05e-01]    [3.96e-01]
# Epoch 2500: train loss improved from 6.05e-01 to 5.59e-01, saving model to model/model-2500.ckpt ...
#
#
# Best model at step 2500:
#   train loss: 5.59e-01
#   test loss: 3.62e-01
#   test metric: [3.96e-01]
#
# 'train' took 0.561321 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2500      [4.54e-01, 1.05e-01]    [2.57e-01, 1.05e-01]    [3.96e-01]
# 2600      [4.39e-01, 1.04e-01]    [2.43e-01, 1.04e-01]    [3.94e-01]
# Epoch 2600: train loss improved from 5.59e-01 to 5.43e-01, saving model to model/model-2600.ckpt ...
#
#
# Best model at step 2600:
#   train loss: 5.43e-01
#   test loss: 3.46e-01
#   test metric: [3.94e-01]
#
# 'train' took 0.565620 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2600      [4.39e-01, 1.04e-01]    [2.43e-01, 1.04e-01]    [3.94e-01]
# 2700      [3.97e-01, 1.01e-01]    [2.06e-01, 1.01e-01]    [3.89e-01]
# Epoch 2700: train loss improved from 5.43e-01 to 4.98e-01, saving model to model/model-2700.ckpt ...
#
#
# Best model at step 2700:
#   train loss: 4.98e-01
#   test loss: 3.08e-01
#   test metric: [3.89e-01]
#
# 'train' took 0.559375 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2700      [3.97e-01, 1.01e-01]    [2.06e-01, 1.01e-01]    [3.89e-01]
# 2800      [5.53e-01, 1.01e-01]    [3.98e-01, 1.01e-01]    [3.88e-01]
#
# Best model at step 2700:
#   train loss: 4.98e-01
#   test loss: 3.08e-01
#   test metric: [3.89e-01]
#
# 'train' took 0.498237 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2800      [5.53e-01, 1.01e-01]    [3.98e-01, 1.01e-01]    [3.88e-01]
# 2900      [1.08e+00, 9.67e-02]    [1.10e+00, 9.67e-02]    [3.79e-01]
#
# Best model at step 2700:
#   train loss: 4.98e-01
#   test loss: 3.08e-01
#   test metric: [3.89e-01]
#
# 'train' took 0.499885 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2900      [1.08e+00, 9.67e-02]    [1.10e+00, 9.67e-02]    [3.79e-01]
# 3000      [2.00e+00, 9.94e-02]    [2.15e+00, 9.94e-02]    [3.88e-01]
#
# Best model at step 2700:
#   train loss: 4.98e-01
#   test loss: 3.08e-01
#   test metric: [3.89e-01]
#
# 'train' took 0.507974 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3000      [2.00e+00, 9.94e-02]    [2.15e+00, 9.94e-02]    [3.88e-01]
# 3100      [4.49e-01, 9.61e-02]    [3.13e-01, 9.61e-02]    [3.79e-01]
#
# Best model at step 2700:
#   train loss: 4.98e-01
#   test loss: 3.08e-01
#   test metric: [3.89e-01]
#
# 'train' took 0.499672 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3100      [4.49e-01, 9.61e-02]    [3.13e-01, 9.61e-02]    [3.79e-01]
# 3200      [1.49e+00, 9.61e-02]    [1.55e+00, 9.61e-02]    [3.81e-01]
#
# Best model at step 2700:
#   train loss: 4.98e-01
#   test loss: 3.08e-01
#   test metric: [3.89e-01]
#
# 'train' took 0.502237 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3200      [1.49e+00, 9.61e-02]    [1.55e+00, 9.61e-02]    [3.81e-01]
# 3300      [4.09e-01, 9.28e-02]    [2.74e-01, 9.28e-02]    [3.71e-01]
#
# Best model at step 2700:
#   train loss: 4.98e-01
#   test loss: 3.08e-01
#   test metric: [3.89e-01]
#
# 'train' took 0.517252 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3300      [4.09e-01, 9.28e-02]    [2.74e-01, 9.28e-02]    [3.71e-01]
# 3400      [5.79e-01, 9.02e-02]    [5.41e-01, 9.02e-02]    [3.66e-01]
#
# Best model at step 2700:
#   train loss: 4.98e-01
#   test loss: 3.08e-01
#   test metric: [3.89e-01]
#
# 'train' took 0.724269 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3400      [5.79e-01, 9.02e-02]    [5.41e-01, 9.02e-02]    [3.66e-01]
# 3500      [5.87e-01, 9.05e-02]    [4.27e-01, 9.05e-02]    [3.66e-01]
#
# Best model at step 2700:
#   train loss: 4.98e-01
#   test loss: 3.08e-01
#   test metric: [3.89e-01]
#
# 'train' took 0.700713 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3500      [5.87e-01, 9.05e-02]    [4.27e-01, 9.05e-02]    [3.66e-01]
# 3600      [2.55e-01, 8.86e-02]    [1.43e-01, 8.86e-02]    [3.63e-01]
# Epoch 3600: train loss improved from 4.98e-01 to 3.44e-01, saving model to model/model-3600.ckpt ...
#
#
# Best model at step 3600:
#   train loss: 3.44e-01
#   test loss: 2.32e-01
#   test metric: [3.63e-01]
#
# 'train' took 0.816177 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3600      [2.55e-01, 8.86e-02]    [1.43e-01, 8.86e-02]    [3.63e-01]
# 3700      [6.27e-01, 8.87e-02]    [5.68e-01, 8.87e-02]    [3.65e-01]
#
# Best model at step 3600:
#   train loss: 3.44e-01
#   test loss: 2.32e-01
#   test metric: [3.63e-01]
#
# 'train' took 0.524547 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3700      [6.27e-01, 8.87e-02]    [5.68e-01, 8.87e-02]    [3.65e-01]
# 3800      [5.33e-01, 8.69e-02]    [4.69e-01, 8.69e-02]    [3.60e-01]
#
# Best model at step 3600:
#   train loss: 3.44e-01
#   test loss: 2.32e-01
#   test metric: [3.63e-01]
#
# 'train' took 0.529463 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3800      [5.33e-01, 8.69e-02]    [4.69e-01, 8.69e-02]    [3.60e-01]
# 3900      [2.33e-01, 8.41e-02]    [1.41e-01, 8.41e-02]    [3.54e-01]
# Epoch 3900: train loss improved from 3.44e-01 to 3.17e-01, saving model to model/model-3900.ckpt ...
#
#
# Best model at step 3900:
#   train loss: 3.17e-01
#   test loss: 2.25e-01
#   test metric: [3.54e-01]
#
# 'train' took 0.640007 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3900      [2.33e-01, 8.41e-02]    [1.41e-01, 8.41e-02]    [3.54e-01]
# 4000      [2.23e-01, 8.27e-02]    [1.33e-01, 8.27e-02]    [3.50e-01]
# Epoch 4000: train loss improved from 3.17e-01 to 3.05e-01, saving model to model/model-4000.ckpt ...
#
#
# Best model at step 4000:
#   train loss: 3.05e-01
#   test loss: 2.16e-01
#   test metric: [3.50e-01]
#
# 'train' took 0.625935 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4000      [2.23e-01, 8.27e-02]    [1.33e-01, 8.27e-02]    [3.50e-01]
# 4100      [2.16e-01, 8.14e-02]    [1.22e-01, 8.14e-02]    [3.48e-01]
# Epoch 4100: train loss improved from 3.05e-01 to 2.97e-01, saving model to model/model-4100.ckpt ...
#
#
# Best model at step 4100:
#   train loss: 2.97e-01
#   test loss: 2.04e-01
#   test metric: [3.48e-01]
#
# 'train' took 0.635078 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4100      [2.16e-01, 8.14e-02]    [1.22e-01, 8.14e-02]    [3.48e-01]
# 4200      [2.04e-01, 7.97e-02]    [1.18e-01, 7.97e-02]    [3.44e-01]
# Epoch 4200: train loss improved from 2.97e-01 to 2.84e-01, saving model to model/model-4200.ckpt ...
#
#
# Best model at step 4200:
#   train loss: 2.84e-01
#   test loss: 1.97e-01
#   test metric: [3.44e-01]
#
# 'train' took 0.644804 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4200      [2.04e-01, 7.97e-02]    [1.18e-01, 7.97e-02]    [3.44e-01]
# 4300      [4.33e+00, 7.87e-02]    [4.02e+00, 7.87e-02]    [3.43e-01]
#
# Best model at step 4200:
#   train loss: 2.84e-01
#   test loss: 1.97e-01
#   test metric: [3.44e-01]
#
# 'train' took 0.561956 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4300      [4.33e+00, 7.87e-02]    [4.02e+00, 7.87e-02]    [3.43e-01]
# 4400      [1.89e-01, 7.66e-02]    [1.09e-01, 7.66e-02]    [3.37e-01]
# Epoch 4400: train loss improved from 2.84e-01 to 2.66e-01, saving model to model/model-4400.ckpt ...
#
#
# Best model at step 4400:
#   train loss: 2.66e-01
#   test loss: 1.86e-01
#   test metric: [3.37e-01]
#
# 'train' took 0.672474 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4400      [1.89e-01, 7.66e-02]    [1.09e-01, 7.66e-02]    [3.37e-01]
# 4500      [1.82e-01, 7.48e-02]    [1.08e-01, 7.48e-02]    [3.33e-01]
# Epoch 4500: train loss improved from 2.66e-01 to 2.57e-01, saving model to model/model-4500.ckpt ...
#
#
# Best model at step 4500:
#   train loss: 2.57e-01
#   test loss: 1.83e-01
#   test metric: [3.33e-01]
#
# 'train' took 0.658365 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4500      [1.82e-01, 7.48e-02]    [1.08e-01, 7.48e-02]    [3.33e-01]
# 4600      [1.75e-01, 7.29e-02]    [1.05e-01, 7.29e-02]    [3.29e-01]
# Epoch 4600: train loss improved from 2.57e-01 to 2.48e-01, saving model to model/model-4600.ckpt ...
#
#
# Best model at step 4600:
#   train loss: 2.48e-01
#   test loss: 1.78e-01
#   test metric: [3.29e-01]
#
# 'train' took 0.659404 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4600      [1.75e-01, 7.29e-02]    [1.05e-01, 7.29e-02]    [3.29e-01]
# 4700      [1.74e-01, 7.12e-02]    [1.10e-01, 7.12e-02]    [3.25e-01]
# Epoch 4700: train loss improved from 2.48e-01 to 2.45e-01, saving model to model/model-4700.ckpt ...
#
#
# Best model at step 4700:
#   train loss: 2.45e-01
#   test loss: 1.81e-01
#   test metric: [3.25e-01]
#
# 'train' took 0.654372 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4700      [1.74e-01, 7.12e-02]    [1.10e-01, 7.12e-02]    [3.25e-01]
# 4800      [3.37e-01, 6.96e-02]    [2.46e-01, 6.96e-02]    [3.19e-01]
#
# Best model at step 4700:
#   train loss: 2.45e-01
#   test loss: 1.81e-01
#   test metric: [3.25e-01]
#
# 'train' took 0.567927 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4800      [3.37e-01, 6.96e-02]    [2.46e-01, 6.96e-02]    [3.19e-01]
# 4900      [1.07e+00, 6.86e-02]    [1.11e+00, 6.86e-02]    [3.22e-01]
#
# Best model at step 4700:
#   train loss: 2.45e-01
#   test loss: 1.81e-01
#   test metric: [3.25e-01]
#
# 'train' took 0.578606 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4900      [1.07e+00, 6.86e-02]    [1.11e+00, 6.86e-02]    [3.22e-01]
# 5000      [1.49e-01, 6.54e-02]    [9.02e-02, 6.54e-02]    [3.11e-01]
# Epoch 5000: train loss improved from 2.45e-01 to 2.14e-01, saving model to model/model-5000.ckpt ...
#
#
# Best model at step 5000:
#   train loss: 2.14e-01
#   test loss: 1.56e-01
#   test metric: [3.11e-01]
#
# 'train' took 0.675360 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [1.49e-01, 6.54e-02]    [9.02e-02, 6.54e-02]    [3.11e-01]
#
# Best model at step 5000:
#   train loss: 2.14e-01
#   test loss: 1.56e-01
#   test metric: [3.11e-01]
#
# 'train' took 0.345633 s
#
# Movie saved as movie_5_8.gif
# Saving loss history to /content/loss.dat ...
# Saving training data to /content/train.dat ...
# Saving test data to /content/test.dat ...
# Restoring model from model/model-5000.ckpt ...
#
# eps_l2 =  0.19461413
# eps_c =  1.2598083
# residual_l2 =  0.008774121
# residual_c =  5.217536

# %%
#frequencies of solution
a = 8
b = 8
#domain boundaries
xmax = np.pi
ymax = np.pi
xmin = 0
ymin = 0
#number of iterations for training
N_iter = 10000
Nx_points = 100
Ny_points = 100

u, u_pr, training_frames = predict_u_with_PINN(a, b, xmin, ymin, xmax, ymax, N_iter, Nx_points, Ny_points, call_save_movie=True, fps = 3)

plot_figures(u, u_pr, xmin, xmax, ymin, ymax, Nx_points, Ny_points)
# Out:
# Warning: 300 points required, but 324 points sampled.
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.072817 s
#
# 'compile' took 0.713707 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [4.06e+03, 5.52e-01]    [4.08e+03, 5.52e-01]    [1.51e+00]
# Epoch 1: train loss improved from inf to 4.06e+03, saving model to model/model-1.ckpt ...
#
# 100       [3.26e+03, 5.28e-01]    [3.24e+03, 5.28e-01]    [1.36e+00]
# Epoch 100: train loss improved from 4.06e+03 to 3.26e+03, saving model to model/model-100.ckpt ...
#
#
# Best model at step 100:
#   train loss: 3.26e+03
#   test loss: 3.24e+03
#   test metric: [1.36e+00]
#
# 'train' took 3.350705 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 100       [3.26e+03, 5.28e-01]    [3.24e+03, 5.28e-01]    [1.36e+00]
# 200       [2.78e+03, 5.25e+00]    [2.76e+03, 5.25e+00]    [4.32e+00]
# Epoch 200: train loss improved from 3.26e+03 to 2.79e+03, saving model to model/model-200.ckpt ...
#
#
# Best model at step 200:
#   train loss: 2.79e+03
#   test loss: 2.77e+03
#   test metric: [4.32e+00]
#
# 'train' took 0.823744 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 200       [2.78e+03, 5.25e+00]    [2.76e+03, 5.25e+00]    [4.32e+00]
# 300       [2.55e+03, 4.49e+00]    [2.61e+03, 4.49e+00]    [3.73e+00]
# Epoch 300: train loss improved from 2.79e+03 to 2.56e+03, saving model to model/model-300.ckpt ...
#
#
# Best model at step 300:
#   train loss: 2.56e+03
#   test loss: 2.62e+03
#   test metric: [3.73e+00]
#
# 'train' took 0.809479 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 300       [2.55e+03, 4.49e+00]    [2.61e+03, 4.49e+00]    [3.73e+00]
# 400       [2.46e+03, 6.85e+00]    [2.70e+03, 6.85e+00]    [4.62e+00]
# Epoch 400: train loss improved from 2.56e+03 to 2.47e+03, saving model to model/model-400.ckpt ...
#
#
# Best model at step 400:
#   train loss: 2.47e+03
#   test loss: 2.71e+03
#   test metric: [4.62e+00]
#
# 'train' took 0.822938 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 400       [2.46e+03, 6.85e+00]    [2.70e+03, 6.85e+00]    [4.62e+00]
# 500       [2.37e+03, 7.12e+00]    [2.77e+03, 7.12e+00]    [4.70e+00]
# Epoch 500: train loss improved from 2.47e+03 to 2.38e+03, saving model to model/model-500.ckpt ...
#
#
# Best model at step 500:
#   train loss: 2.38e+03
#   test loss: 2.77e+03
#   test metric: [4.70e+00]
#
# 'train' took 0.818259 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 500       [2.37e+03, 7.12e+00]    [2.77e+03, 7.12e+00]    [4.70e+00]
# 600       [2.30e+03, 7.30e+00]    [2.80e+03, 7.30e+00]    [4.80e+00]
# Epoch 600: train loss improved from 2.38e+03 to 2.31e+03, saving model to model/model-600.ckpt ...
#
#
# Best model at step 600:
#   train loss: 2.31e+03
#   test loss: 2.81e+03
#   test metric: [4.80e+00]
#
# 'train' took 0.857910 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 600       [2.30e+03, 7.30e+00]    [2.80e+03, 7.30e+00]    [4.80e+00]
# 700       [2.10e+03, 3.09e+00]    [2.67e+03, 3.09e+00]    [3.31e+00]
# Epoch 700: train loss improved from 2.31e+03 to 2.11e+03, saving model to model/model-700.ckpt ...
#
#
# Best model at step 700:
#   train loss: 2.11e+03
#   test loss: 2.68e+03
#   test metric: [3.31e+00]
#
# 'train' took 1.186766 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 700       [2.10e+03, 3.09e+00]    [2.67e+03, 3.09e+00]    [3.31e+00]
# 800       [2.00e+03, 5.03e-01]    [2.74e+03, 5.03e-01]    [1.33e+00]
# Epoch 800: train loss improved from 2.11e+03 to 2.00e+03, saving model to model/model-800.ckpt ...
#
#
# Best model at step 800:
#   train loss: 2.00e+03
#   test loss: 2.74e+03
#   test metric: [1.33e+00]
#
# 'train' took 1.194784 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 800       [2.00e+03, 5.03e-01]    [2.74e+03, 5.03e-01]    [1.33e+00]
# 900       [1.96e+03, 2.64e+00]    [2.72e+03, 2.64e+00]    [2.61e+00]
# Epoch 900: train loss improved from 2.00e+03 to 1.96e+03, saving model to model/model-900.ckpt ...
#
#
# Best model at step 900:
#   train loss: 1.96e+03
#   test loss: 2.73e+03
#   test metric: [2.61e+00]
#
# 'train' took 0.867582 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 900       [1.96e+03, 2.64e+00]    [2.72e+03, 2.64e+00]    [2.61e+00]
# 1000      [1.87e+03, 2.90e+00]    [2.67e+03, 2.90e+00]    [2.91e+00]
# Epoch 1000: train loss improved from 1.96e+03 to 1.87e+03, saving model to model/model-1000.ckpt ...
#
#
# Best model at step 1000:
#   train loss: 1.87e+03
#   test loss: 2.67e+03
#   test metric: [2.91e+00]
#
# 'train' took 0.891601 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1000      [1.87e+03, 2.90e+00]    [2.67e+03, 2.90e+00]    [2.91e+00]
# 1100      [1.79e+03, 1.34e+00]    [2.60e+03, 1.34e+00]    [2.09e+00]
# Epoch 1100: train loss improved from 1.87e+03 to 1.79e+03, saving model to model/model-1100.ckpt ...
#
#
# Best model at step 1100:
#   train loss: 1.79e+03
#   test loss: 2.60e+03
#   test metric: [2.09e+00]
#
# 'train' took 0.914003 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1100      [1.79e+03, 1.34e+00]    [2.60e+03, 1.34e+00]    [2.09e+00]
# 1200      [1.76e+03, 8.44e-01]    [2.61e+03, 8.44e-01]    [1.52e+00]
# Epoch 1200: train loss improved from 1.79e+03 to 1.76e+03, saving model to model/model-1200.ckpt ...
#
#
# Best model at step 1200:
#   train loss: 1.76e+03
#   test loss: 2.61e+03
#   test metric: [1.52e+00]
#
# 'train' took 0.903441 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1200      [1.76e+03, 8.44e-01]    [2.61e+03, 8.44e-01]    [1.52e+00]
# 1300      [1.75e+03, 1.24e+00]    [2.61e+03, 1.24e+00]    [1.68e+00]
# Epoch 1300: train loss improved from 1.76e+03 to 1.75e+03, saving model to model/model-1300.ckpt ...
#
#
# Best model at step 1300:
#   train loss: 1.75e+03
#   test loss: 2.61e+03
#   test metric: [1.68e+00]
#
# 'train' took 0.941465 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1300      [1.75e+03, 1.24e+00]    [2.61e+03, 1.24e+00]    [1.68e+00]
# 1400      [1.73e+03, 2.04e+00]    [2.62e+03, 2.04e+00]    [2.15e+00]
# Epoch 1400: train loss improved from 1.75e+03 to 1.73e+03, saving model to model/model-1400.ckpt ...
#
#
# Best model at step 1400:
#   train loss: 1.73e+03
#   test loss: 2.62e+03
#   test metric: [2.15e+00]
#
# 'train' took 0.910547 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1400      [1.73e+03, 2.04e+00]    [2.62e+03, 2.04e+00]    [2.15e+00]
# 1500      [1.70e+03, 2.93e+00]    [2.63e+03, 2.93e+00]    [2.60e+00]
# Epoch 1500: train loss improved from 1.73e+03 to 1.70e+03, saving model to model/model-1500.ckpt ...
#
#
# Best model at step 1500:
#   train loss: 1.70e+03
#   test loss: 2.63e+03
#   test metric: [2.60e+00]
#
# 'train' took 0.913911 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1500      [1.70e+03, 2.93e+00]    [2.63e+03, 2.93e+00]    [2.60e+00]
# 1600      [1.66e+03, 2.14e+00]    [2.60e+03, 2.14e+00]    [2.31e+00]
# Epoch 1600: train loss improved from 1.70e+03 to 1.66e+03, saving model to model/model-1600.ckpt ...
#
#
# Best model at step 1600:
#   train loss: 1.66e+03
#   test loss: 2.60e+03
#   test metric: [2.31e+00]
#
# 'train' took 0.935242 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1600      [1.66e+03, 2.14e+00]    [2.60e+03, 2.14e+00]    [2.31e+00]
# 1700      [1.60e+03, 1.89e+00]    [2.58e+03, 1.89e+00]    [2.33e+00]
# Epoch 1700: train loss improved from 1.66e+03 to 1.60e+03, saving model to model/model-1700.ckpt ...
#
#
# Best model at step 1700:
#   train loss: 1.60e+03
#   test loss: 2.58e+03
#   test metric: [2.33e+00]
#
# 'train' took 0.945857 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1700      [1.60e+03, 1.89e+00]    [2.58e+03, 1.89e+00]    [2.33e+00]
# 1800      [1.58e+03, 1.16e+00]    [2.59e+03, 1.16e+00]    [1.79e+00]
# Epoch 1800: train loss improved from 1.60e+03 to 1.58e+03, saving model to model/model-1800.ckpt ...
#
#
# Best model at step 1800:
#   train loss: 1.58e+03
#   test loss: 2.59e+03
#   test metric: [1.79e+00]
#
# 'train' took 0.993471 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1800      [1.58e+03, 1.16e+00]    [2.59e+03, 1.16e+00]    [1.79e+00]
# 1900      [1.57e+03, 1.01e+00]    [2.61e+03, 1.01e+00]    [1.54e+00]
# Epoch 1900: train loss improved from 1.58e+03 to 1.57e+03, saving model to model/model-1900.ckpt ...
#
#
# Best model at step 1900:
#   train loss: 1.57e+03
#   test loss: 2.61e+03
#   test metric: [1.54e+00]
#
# 'train' took 1.100466 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1900      [1.57e+03, 1.01e+00]    [2.61e+03, 1.01e+00]    [1.54e+00]
# 2000      [1.56e+03, 1.17e+00]    [2.62e+03, 1.17e+00]    [1.56e+00]
# Epoch 2000: train loss improved from 1.57e+03 to 1.56e+03, saving model to model/model-2000.ckpt ...
#
#
# Best model at step 2000:
#   train loss: 1.56e+03
#   test loss: 2.62e+03
#   test metric: [1.56e+00]
#
# 'train' took 1.385558 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2000      [1.56e+03, 1.17e+00]    [2.62e+03, 1.17e+00]    [1.56e+00]
# 2100      [1.54e+03, 1.45e+00]    [2.65e+03, 1.45e+00]    [1.69e+00]
# Epoch 2100: train loss improved from 1.56e+03 to 1.54e+03, saving model to model/model-2100.ckpt ...
#
#
# Best model at step 2100:
#   train loss: 1.54e+03
#   test loss: 2.65e+03
#   test metric: [1.69e+00]
#
# 'train' took 1.047900 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2100      [1.54e+03, 1.45e+00]    [2.65e+03, 1.45e+00]    [1.69e+00]
# 2200      [1.54e+03, 1.79e+00]    [2.63e+03, 1.79e+00]    [1.86e+00]
# Epoch 2200: train loss improved from 1.54e+03 to 1.54e+03, saving model to model/model-2200.ckpt ...
#
#
# Best model at step 2200:
#   train loss: 1.54e+03
#   test loss: 2.64e+03
#   test metric: [1.86e+00]
#
# 'train' took 0.994706 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2200      [1.54e+03, 1.79e+00]    [2.63e+03, 1.79e+00]    [1.86e+00]
# 2300      [1.50e+03, 2.22e+00]    [2.66e+03, 2.22e+00]    [2.06e+00]
# Epoch 2300: train loss improved from 1.54e+03 to 1.50e+03, saving model to model/model-2300.ckpt ...
#
#
# Best model at step 2300:
#   train loss: 1.50e+03
#   test loss: 2.66e+03
#   test metric: [2.06e+00]
#
# 'train' took 0.998649 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2300      [1.50e+03, 2.22e+00]    [2.66e+03, 2.22e+00]    [2.06e+00]
# 2400      [1.49e+03, 2.85e+00]    [2.66e+03, 2.85e+00]    [2.35e+00]
# Epoch 2400: train loss improved from 1.50e+03 to 1.49e+03, saving model to model/model-2400.ckpt ...
#
#
# Best model at step 2400:
#   train loss: 1.49e+03
#   test loss: 2.66e+03
#   test metric: [2.35e+00]
#
# 'train' took 1.000973 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2400      [1.49e+03, 2.85e+00]    [2.66e+03, 2.85e+00]    [2.35e+00]
# 2500      [1.45e+03, 3.69e+00]    [2.60e+03, 3.69e+00]    [2.72e+00]
# Epoch 2500: train loss improved from 1.49e+03 to 1.45e+03, saving model to model/model-2500.ckpt ...
#
#
# Best model at step 2500:
#   train loss: 1.45e+03
#   test loss: 2.60e+03
#   test metric: [2.72e+00]
#
# 'train' took 0.999853 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2500      [1.45e+03, 3.69e+00]    [2.60e+03, 3.69e+00]    [2.72e+00]
# 2600      [1.40e+03, 4.51e+00]    [2.54e+03, 4.51e+00]    [3.08e+00]
# Epoch 2600: train loss improved from 1.45e+03 to 1.41e+03, saving model to model/model-2600.ckpt ...
#
#
# Best model at step 2600:
#   train loss: 1.41e+03
#   test loss: 2.55e+03
#   test metric: [3.08e+00]
#
# 'train' took 1.013975 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2600      [1.40e+03, 4.51e+00]    [2.54e+03, 4.51e+00]    [3.08e+00]
# 2700      [1.37e+03, 4.93e+00]    [2.51e+03, 4.93e+00]    [3.26e+00]
# Epoch 2700: train loss improved from 1.41e+03 to 1.38e+03, saving model to model/model-2700.ckpt ...
#
#
# Best model at step 2700:
#   train loss: 1.38e+03
#   test loss: 2.52e+03
#   test metric: [3.26e+00]
#
# 'train' took 1.009660 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2700      [1.37e+03, 4.93e+00]    [2.51e+03, 4.93e+00]    [3.26e+00]
# 2800      [1.36e+03, 5.12e+00]    [2.49e+03, 5.12e+00]    [3.35e+00]
# Epoch 2800: train loss improved from 1.38e+03 to 1.37e+03, saving model to model/model-2800.ckpt ...
#
#
# Best model at step 2800:
#   train loss: 1.37e+03
#   test loss: 2.50e+03
#   test metric: [3.35e+00]
#
# 'train' took 1.008982 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2800      [1.36e+03, 5.12e+00]    [2.49e+03, 5.12e+00]    [3.35e+00]
# 2900      [1.36e+03, 5.12e+00]    [2.49e+03, 5.12e+00]    [3.36e+00]
# Epoch 2900: train loss improved from 1.37e+03 to 1.36e+03, saving model to model/model-2900.ckpt ...
#
#
# Best model at step 2900:
#   train loss: 1.36e+03
#   test loss: 2.49e+03
#   test metric: [3.36e+00]
#
# 'train' took 1.029250 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2900      [1.36e+03, 5.12e+00]    [2.49e+03, 5.12e+00]    [3.36e+00]
# 3000      [1.33e+03, 4.95e+00]    [2.48e+03, 4.95e+00]    [3.31e+00]
# Epoch 3000: train loss improved from 1.36e+03 to 1.34e+03, saving model to model/model-3000.ckpt ...
#
#
# Best model at step 3000:
#   train loss: 1.34e+03
#   test loss: 2.48e+03
#   test metric: [3.31e+00]
#
# 'train' took 1.113054 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3000      [1.33e+03, 4.95e+00]    [2.48e+03, 4.95e+00]    [3.31e+00]
# 3100      [1.33e+03, 4.73e+00]    [2.46e+03, 4.73e+00]    [3.24e+00]
#
# Best model at step 3000:
#   train loss: 1.34e+03
#   test loss: 2.48e+03
#   test metric: [3.31e+00]
#
# 'train' took 1.225353 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3100      [1.33e+03, 4.73e+00]    [2.46e+03, 4.73e+00]    [3.24e+00]
# 3200      [1.31e+03, 4.56e+00]    [2.46e+03, 4.56e+00]    [3.20e+00]
# Epoch 3200: train loss improved from 1.34e+03 to 1.32e+03, saving model to model/model-3200.ckpt ...
#
#
# Best model at step 3200:
#   train loss: 1.32e+03
#   test loss: 2.47e+03
#   test metric: [3.20e+00]
#
# 'train' took 1.322916 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3200      [1.31e+03, 4.56e+00]    [2.46e+03, 4.56e+00]    [3.20e+00]
# 3300      [1.29e+03, 4.46e+00]    [2.48e+03, 4.46e+00]    [3.19e+00]
# Epoch 3300: train loss improved from 1.32e+03 to 1.30e+03, saving model to model/model-3300.ckpt ...
#
#
# Best model at step 3300:
#   train loss: 1.30e+03
#   test loss: 2.48e+03
#   test metric: [3.19e+00]
#
# 'train' took 1.113187 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3300      [1.29e+03, 4.46e+00]    [2.48e+03, 4.46e+00]    [3.19e+00]
# 3400      [1.28e+03, 4.47e+00]    [2.50e+03, 4.47e+00]    [3.21e+00]
# Epoch 3400: train loss improved from 1.30e+03 to 1.29e+03, saving model to model/model-3400.ckpt ...
#
#
# Best model at step 3400:
#   train loss: 1.29e+03
#   test loss: 2.50e+03
#   test metric: [3.21e+00]
#
# 'train' took 1.094004 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3400      [1.28e+03, 4.47e+00]    [2.50e+03, 4.47e+00]    [3.21e+00]
# 3500      [1.27e+03, 4.54e+00]    [2.52e+03, 4.54e+00]    [3.26e+00]
# Epoch 3500: train loss improved from 1.29e+03 to 1.28e+03, saving model to model/model-3500.ckpt ...
#
#
# Best model at step 3500:
#   train loss: 1.28e+03
#   test loss: 2.52e+03
#   test metric: [3.26e+00]
#
# 'train' took 1.089162 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3500      [1.27e+03, 4.54e+00]    [2.52e+03, 4.54e+00]    [3.26e+00]
# 3600      [1.27e+03, 4.69e+00]    [2.54e+03, 4.69e+00]    [3.34e+00]
# Epoch 3600: train loss improved from 1.28e+03 to 1.27e+03, saving model to model/model-3600.ckpt ...
#
#
# Best model at step 3600:
#   train loss: 1.27e+03
#   test loss: 2.55e+03
#   test metric: [3.34e+00]
#
# 'train' took 1.096900 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3600      [1.27e+03, 4.69e+00]    [2.54e+03, 4.69e+00]    [3.34e+00]
# 3700      [1.27e+03, 4.89e+00]    [2.57e+03, 4.89e+00]    [3.43e+00]
#
# Best model at step 3600:
#   train loss: 1.27e+03
#   test loss: 2.55e+03
#   test metric: [3.34e+00]
#
# 'train' took 0.900614 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3700      [1.27e+03, 4.89e+00]    [2.57e+03, 4.89e+00]    [3.43e+00]
# 3800      [1.24e+03, 5.10e+00]    [2.59e+03, 5.10e+00]    [3.53e+00]
# Epoch 3800: train loss improved from 1.27e+03 to 1.25e+03, saving model to model/model-3800.ckpt ...
#
#
# Best model at step 3800:
#   train loss: 1.25e+03
#   test loss: 2.60e+03
#   test metric: [3.53e+00]
#
# 'train' took 1.100028 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3800      [1.24e+03, 5.10e+00]    [2.59e+03, 5.10e+00]    [3.53e+00]
# 3900      [1.21e+03, 5.26e+00]    [2.61e+03, 5.26e+00]    [3.60e+00]
# Epoch 3900: train loss improved from 1.25e+03 to 1.22e+03, saving model to model/model-3900.ckpt ...
#
#
# Best model at step 3900:
#   train loss: 1.22e+03
#   test loss: 2.61e+03
#   test metric: [3.60e+00]
#
# 'train' took 1.092186 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 3900      [1.21e+03, 5.26e+00]    [2.61e+03, 5.26e+00]    [3.60e+00]
# 4000      [1.19e+03, 5.35e+00]    [2.61e+03, 5.35e+00]    [3.63e+00]
# Epoch 4000: train loss improved from 1.22e+03 to 1.20e+03, saving model to model/model-4000.ckpt ...
#
#
# Best model at step 4000:
#   train loss: 1.20e+03
#   test loss: 2.62e+03
#   test metric: [3.63e+00]
#
# 'train' took 1.104173 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4000      [1.19e+03, 5.35e+00]    [2.61e+03, 5.35e+00]    [3.63e+00]
# 4100      [1.20e+03, 5.43e+00]    [2.62e+03, 5.43e+00]    [3.65e+00]
#
# Best model at step 4000:
#   train loss: 1.20e+03
#   test loss: 2.62e+03
#   test metric: [3.63e+00]
#
# 'train' took 0.953748 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4100      [1.20e+03, 5.43e+00]    [2.62e+03, 5.43e+00]    [3.65e+00]
# 4200      [1.16e+03, 5.55e+00]    [2.66e+03, 5.55e+00]    [3.70e+00]
# Epoch 4200: train loss improved from 1.20e+03 to 1.17e+03, saving model to model/model-4200.ckpt ...
#
#
# Best model at step 4200:
#   train loss: 1.17e+03
#   test loss: 2.67e+03
#   test metric: [3.70e+00]
#
# 'train' took 1.656094 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4200      [1.16e+03, 5.55e+00]    [2.66e+03, 5.55e+00]    [3.70e+00]
# 4300      [1.16e+03, 5.73e+00]    [2.74e+03, 5.73e+00]    [3.76e+00]
# Epoch 4300: train loss improved from 1.17e+03 to 1.16e+03, saving model to model/model-4300.ckpt ...
#
#
# Best model at step 4300:
#   train loss: 1.16e+03
#   test loss: 2.74e+03
#   test metric: [3.76e+00]
#
# 'train' took 1.255263 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4300      [1.16e+03, 5.73e+00]    [2.74e+03, 5.73e+00]    [3.76e+00]
# 4400      [1.13e+03, 5.89e+00]    [2.76e+03, 5.89e+00]    [3.81e+00]
# Epoch 4400: train loss improved from 1.16e+03 to 1.13e+03, saving model to model/model-4400.ckpt ...
#
#
# Best model at step 4400:
#   train loss: 1.13e+03
#   test loss: 2.77e+03
#   test metric: [3.81e+00]
#
# 'train' took 1.205121 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4400      [1.13e+03, 5.89e+00]    [2.76e+03, 5.89e+00]    [3.81e+00]
# 4500      [1.12e+03, 6.03e+00]    [2.80e+03, 6.03e+00]    [3.86e+00]
# Epoch 4500: train loss improved from 1.13e+03 to 1.12e+03, saving model to model/model-4500.ckpt ...
#
#
# Best model at step 4500:
#   train loss: 1.12e+03
#   test loss: 2.80e+03
#   test metric: [3.86e+00]
#
# 'train' took 1.194801 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4500      [1.12e+03, 6.03e+00]    [2.80e+03, 6.03e+00]    [3.86e+00]
# 4600      [1.10e+03, 6.08e+00]    [2.91e+03, 6.08e+00]    [3.87e+00]
# Epoch 4600: train loss improved from 1.12e+03 to 1.11e+03, saving model to model/model-4600.ckpt ...
#
#
# Best model at step 4600:
#   train loss: 1.11e+03
#   test loss: 2.91e+03
#   test metric: [3.87e+00]
#
# 'train' took 1.168029 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4600      [1.10e+03, 6.08e+00]    [2.91e+03, 6.08e+00]    [3.87e+00]
# 4700      [1.09e+03, 6.07e+00]    [2.92e+03, 6.07e+00]    [3.88e+00]
# Epoch 4700: train loss improved from 1.11e+03 to 1.10e+03, saving model to model/model-4700.ckpt ...
#
#
# Best model at step 4700:
#   train loss: 1.10e+03
#   test loss: 2.92e+03
#   test metric: [3.88e+00]
#
# 'train' took 1.175210 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4700      [1.09e+03, 6.07e+00]    [2.92e+03, 6.07e+00]    [3.88e+00]
# 4800      [1.07e+03, 6.30e+00]    [3.06e+03, 6.30e+00]    [4.02e+00]
# Epoch 4800: train loss improved from 1.10e+03 to 1.07e+03, saving model to model/model-4800.ckpt ...
#
#
# Best model at step 4800:
#   train loss: 1.07e+03
#   test loss: 3.07e+03
#   test metric: [4.02e+00]
#
# 'train' took 1.182447 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4800      [1.07e+03, 6.30e+00]    [3.06e+03, 6.30e+00]    [4.02e+00]
# 4900      [1.05e+03, 5.39e+00]    [3.05e+03, 5.39e+00]    [3.76e+00]
# Epoch 4900: train loss improved from 1.07e+03 to 1.05e+03, saving model to model/model-4900.ckpt ...
#
#
# Best model at step 4900:
#   train loss: 1.05e+03
#   test loss: 3.06e+03
#   test metric: [3.76e+00]
#
# 'train' took 1.190055 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 4900      [1.05e+03, 5.39e+00]    [3.05e+03, 5.39e+00]    [3.76e+00]
# 5000      [1.03e+03, 4.81e+00]    [3.16e+03, 4.81e+00]    [3.56e+00]
# Epoch 5000: train loss improved from 1.05e+03 to 1.04e+03, saving model to model/model-5000.ckpt ...
#
#
# Best model at step 5000:
#   train loss: 1.04e+03
#   test loss: 3.17e+03
#   test metric: [3.56e+00]
#
# 'train' took 1.173713 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 5000      [1.03e+03, 4.81e+00]    [3.16e+03, 4.81e+00]    [3.56e+00]
#
# Best model at step 5000:
#   train loss: 1.04e+03
#   test loss: 3.17e+03
#   test metric: [3.56e+00]
#
# 'train' took 0.772638 s
#
# Movie saved as movie_8_8.gif
# Saving loss history to /content/loss.dat ...
# Saving training data to /content/train.dat ...
# Saving test data to /content/test.dat ...
# Restoring model from model/model-5000.ckpt ...
#
# eps_l2 =  3.155432
# eps_c =  3.9980245
# residual_l2 =  0.8156832
# residual_c =  244.849

# %%
#frequencies of solution
a = 15
b = 15
#domain boundaries
xmax = np.pi
ymax = np.pi
xmin = 0
ymin = 0
#number of iterations for training
N_iter = 5000
Nx_points = 100
Ny_points = 100

u, u_pr, training_frames = predict_u_with_PINN(a, b, xmin, ymin, xmax, ymax, N_iter, Nx_points, Ny_points, call_save_movie=True, fps = 3)

plot_figures(u, u_pr, xmin, xmax, ymin, ymax, Nx_points, Ny_points)
# Out:
# Warning: 300 points required, but 324 points sampled.
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.075580 s
#
# 'compile' took 1.114966 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 0         [5.07e+04, 2.74e-01]    [5.05e+04, 2.74e-01]    [1.05e+00]
# Epoch 1: train loss improved from inf to 5.07e+04, saving model to model/model-1.ckpt ...
#
# 100       [5.00e+04, 7.03e-01]    [5.03e+04, 7.03e-01]    [1.43e+00]
# Epoch 100: train loss improved from 5.07e+04 to 5.00e+04, saving model to model/model-100.ckpt ...
#
#
# Best model at step 100:
#   train loss: 5.00e+04
#   test loss: 5.03e+04
#   test metric: [1.43e+00]
#
# 'train' took 12.535591 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 100       [5.00e+04, 7.03e-01]    [5.03e+04, 7.03e-01]    [1.43e+00]
# 200       [4.41e+04, 8.41e-01]    [4.52e+04, 8.41e-01]    [1.86e+00]
# Epoch 200: train loss improved from 5.00e+04 to 4.41e+04, saving model to model/model-200.ckpt ...
#
#
# Best model at step 200:
#   train loss: 4.41e+04
#   test loss: 4.52e+04
#   test metric: [1.86e+00]
#
# 'train' took 8.138171 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 200       [4.41e+04, 8.41e-01]    [4.52e+04, 8.41e-01]    [1.86e+00]
# 300       [4.09e+04, 4.09e+00]    [4.03e+04, 4.09e+00]    [4.46e+00]
# Epoch 300: train loss improved from 4.41e+04 to 4.09e+04, saving model to model/model-300.ckpt ...
#
#
# Best model at step 300:
#   train loss: 4.09e+04
#   test loss: 4.03e+04
#   test metric: [4.46e+00]
#
# 'train' took 7.725080 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 300       [4.09e+04, 4.09e+00]    [4.03e+04, 4.09e+00]    [4.46e+00]
# 400       [3.87e+04, 5.35e+00]    [3.94e+04, 5.35e+00]    [3.93e+00]
# Epoch 400: train loss improved from 4.09e+04 to 3.87e+04, saving model to model/model-400.ckpt ...
#
#
# Best model at step 400:
#   train loss: 3.87e+04
#   test loss: 3.94e+04
#   test metric: [3.93e+00]
#
# 'train' took 8.133391 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 400       [3.87e+04, 5.35e+00]    [3.94e+04, 5.35e+00]    [3.93e+00]
# 500       [3.78e+04, 7.94e+00]    [4.00e+04, 7.94e+00]    [5.04e+00]
# Epoch 500: train loss improved from 3.87e+04 to 3.78e+04, saving model to model/model-500.ckpt ...
#
#
# Best model at step 500:
#   train loss: 3.78e+04
#   test loss: 4.00e+04
#   test metric: [5.04e+00]
#
# 'train' took 8.011288 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 500       [3.78e+04, 7.94e+00]    [4.00e+04, 7.94e+00]    [5.04e+00]
# 600       [3.68e+04, 3.29e+00]    [4.03e+04, 3.29e+00]    [3.22e+00]
# Epoch 600: train loss improved from 3.78e+04 to 3.68e+04, saving model to model/model-600.ckpt ...
#
#
# Best model at step 600:
#   train loss: 3.68e+04
#   test loss: 4.03e+04
#   test metric: [3.22e+00]
#
# 'train' took 7.441237 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 600       [3.68e+04, 3.29e+00]    [4.03e+04, 3.29e+00]    [3.22e+00]
# 700       [3.58e+04, 4.13e+00]    [3.88e+04, 4.13e+00]    [3.47e+00]
# Epoch 700: train loss improved from 3.68e+04 to 3.58e+04, saving model to model/model-700.ckpt ...
#
#
# Best model at step 700:
#   train loss: 3.58e+04
#   test loss: 3.88e+04
#   test metric: [3.47e+00]
#
# 'train' took 8.293737 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 700       [3.58e+04, 4.13e+00]    [3.88e+04, 4.13e+00]    [3.47e+00]
# 800       [3.44e+04, 3.99e+00]    [3.67e+04, 3.99e+00]    [3.48e+00]
# Epoch 800: train loss improved from 3.58e+04 to 3.44e+04, saving model to model/model-800.ckpt ...
#
#
# Best model at step 800:
#   train loss: 3.44e+04
#   test loss: 3.67e+04
#   test metric: [3.48e+00]
#
# 'train' took 8.014597 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 800       [3.44e+04, 3.99e+00]    [3.67e+04, 3.99e+00]    [3.48e+00]
# 900       [3.40e+04, 5.24e+00]    [3.79e+04, 5.24e+00]    [3.88e+00]
# Epoch 900: train loss improved from 3.44e+04 to 3.40e+04, saving model to model/model-900.ckpt ...
#
#
# Best model at step 900:
#   train loss: 3.40e+04
#   test loss: 3.79e+04
#   test metric: [3.88e+00]
#
# 'train' took 7.361675 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 900       [3.40e+04, 5.24e+00]    [3.79e+04, 5.24e+00]    [3.88e+00]
# 1000      [3.36e+04, 7.51e+00]    [3.93e+04, 7.51e+00]    [4.57e+00]
# Epoch 1000: train loss improved from 3.40e+04 to 3.36e+04, saving model to model/model-1000.ckpt ...
#
#
# Best model at step 1000:
#   train loss: 3.36e+04
#   test loss: 3.93e+04
#   test metric: [4.57e+00]
#
# 'train' took 7.726296 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1000      [3.36e+04, 7.51e+00]    [3.93e+04, 7.51e+00]    [4.57e+00]
# 1100      [3.32e+04, 8.55e+00]    [3.91e+04, 8.55e+00]    [4.91e+00]
# Epoch 1100: train loss improved from 3.36e+04 to 3.32e+04, saving model to model/model-1100.ckpt ...
#
#
# Best model at step 1100:
#   train loss: 3.32e+04
#   test loss: 3.91e+04
#   test metric: [4.91e+00]
#
# 'train' took 6.896771 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1100      [3.32e+04, 8.55e+00]    [3.91e+04, 8.55e+00]    [4.91e+00]
# 1200      [3.31e+04, 7.27e+00]    [3.81e+04, 7.27e+00]    [4.68e+00]
# Epoch 1200: train loss improved from 3.32e+04 to 3.31e+04, saving model to model/model-1200.ckpt ...
#
#
# Best model at step 1200:
#   train loss: 3.31e+04
#   test loss: 3.81e+04
#   test metric: [4.68e+00]
#
# 'train' took 7.778716 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1200      [3.31e+04, 7.27e+00]    [3.81e+04, 7.27e+00]    [4.68e+00]
# 1300      [3.22e+04, 5.93e+00]    [3.83e+04, 5.93e+00]    [4.32e+00]
# Epoch 1300: train loss improved from 3.31e+04 to 3.22e+04, saving model to model/model-1300.ckpt ...
#
#
# Best model at step 1300:
#   train loss: 3.22e+04
#   test loss: 3.83e+04
#   test metric: [4.32e+00]
#
# 'train' took 7.539114 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1300      [3.22e+04, 5.93e+00]    [3.83e+04, 5.93e+00]    [4.32e+00]
# 1400      [3.19e+04, 5.61e+00]    [3.88e+04, 5.61e+00]    [4.23e+00]
# Epoch 1400: train loss improved from 3.22e+04 to 3.19e+04, saving model to model/model-1400.ckpt ...
#
#
# Best model at step 1400:
#   train loss: 3.19e+04
#   test loss: 3.88e+04
#   test metric: [4.23e+00]
#
# 'train' took 7.518292 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1400      [3.19e+04, 5.61e+00]    [3.88e+04, 5.61e+00]    [4.23e+00]
# 1500      [3.15e+04, 5.46e+00]    [3.93e+04, 5.46e+00]    [4.13e+00]
# Epoch 1500: train loss improved from 3.19e+04 to 3.15e+04, saving model to model/model-1500.ckpt ...
#
#
# Best model at step 1500:
#   train loss: 3.15e+04
#   test loss: 3.93e+04
#   test metric: [4.13e+00]
#
# 'train' took 7.808569 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1500      [3.15e+04, 5.46e+00]    [3.93e+04, 5.46e+00]    [4.13e+00]
# 1600      [3.11e+04, 4.29e+00]    [3.91e+04, 4.29e+00]    [3.65e+00]
# Epoch 1600: train loss improved from 3.15e+04 to 3.11e+04, saving model to model/model-1600.ckpt ...
#
#
# Best model at step 1600:
#   train loss: 3.11e+04
#   test loss: 3.91e+04
#   test metric: [3.65e+00]
#
# 'train' took 7.831690 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1600      [3.11e+04, 4.29e+00]    [3.91e+04, 4.29e+00]    [3.65e+00]
# 1700      [3.05e+04, 3.29e+00]    [3.95e+04, 3.29e+00]    [3.01e+00]
# Epoch 1700: train loss improved from 3.11e+04 to 3.05e+04, saving model to model/model-1700.ckpt ...
#
#
# Best model at step 1700:
#   train loss: 3.05e+04
#   test loss: 3.95e+04
#   test metric: [3.01e+00]
#
# 'train' took 7.380360 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1700      [3.05e+04, 3.29e+00]    [3.95e+04, 3.29e+00]    [3.01e+00]
# 1800      [2.98e+04, 2.88e+00]    [3.90e+04, 2.88e+00]    [2.83e+00]
# Epoch 1800: train loss improved from 3.05e+04 to 2.98e+04, saving model to model/model-1800.ckpt ...
#
#
# Best model at step 1800:
#   train loss: 2.98e+04
#   test loss: 3.90e+04
#   test metric: [2.83e+00]
#
# 'train' took 8.015060 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1800      [2.98e+04, 2.88e+00]    [3.90e+04, 2.88e+00]    [2.83e+00]
# 1900      [2.91e+04, 2.76e+00]    [3.80e+04, 2.76e+00]    [2.72e+00]
# Epoch 1900: train loss improved from 2.98e+04 to 2.91e+04, saving model to model/model-1900.ckpt ...
#
#
# Best model at step 1900:
#   train loss: 2.91e+04
#   test loss: 3.80e+04
#   test metric: [2.72e+00]
#
# 'train' took 7.897552 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 1900      [2.91e+04, 2.76e+00]    [3.80e+04, 2.76e+00]    [2.72e+00]
# 2000      [2.85e+04, 3.28e+00]    [3.71e+04, 3.28e+00]    [3.13e+00]
# Epoch 2000: train loss improved from 2.91e+04 to 2.85e+04, saving model to model/model-2000.ckpt ...
#
#
# Best model at step 2000:
#   train loss: 2.85e+04
#   test loss: 3.71e+04
#   test metric: [3.13e+00]
#
# 'train' took 7.485278 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2000      [2.85e+04, 3.28e+00]    [3.71e+04, 3.28e+00]    [3.13e+00]
# 2100      [2.84e+04, 4.21e+00]    [3.71e+04, 4.21e+00]    [3.64e+00]
# Epoch 2100: train loss improved from 2.85e+04 to 2.84e+04, saving model to model/model-2100.ckpt ...
#
#
# Best model at step 2100:
#   train loss: 2.84e+04
#   test loss: 3.71e+04
#   test metric: [3.64e+00]
#
# 'train' took 8.067083 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2100      [2.84e+04, 4.21e+00]    [3.71e+04, 4.21e+00]    [3.64e+00]
# 2200      [2.81e+04, 4.18e+00]    [3.76e+04, 4.18e+00]    [3.72e+00]
# Epoch 2200: train loss improved from 2.84e+04 to 2.81e+04, saving model to model/model-2200.ckpt ...
#
#
# Best model at step 2200:
#   train loss: 2.81e+04
#   test loss: 3.76e+04
#   test metric: [3.72e+00]
#
# 'train' took 7.893234 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2200      [2.81e+04, 4.18e+00]    [3.76e+04, 4.18e+00]    [3.72e+00]
# 2300      [2.78e+04, 4.42e+00]    [3.86e+04, 4.42e+00]    [3.74e+00]
# Epoch 2300: train loss improved from 2.81e+04 to 2.78e+04, saving model to model/model-2300.ckpt ...
#
#
# Best model at step 2300:
#   train loss: 2.78e+04
#   test loss: 3.86e+04
#   test metric: [3.74e+00]
#
# 'train' took 7.422427 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2300      [2.78e+04, 4.42e+00]    [3.86e+04, 4.42e+00]    [3.74e+00]
# 2400      [2.74e+04, 4.32e+00]    [3.92e+04, 4.32e+00]    [3.73e+00]
# Epoch 2400: train loss improved from 2.78e+04 to 2.74e+04, saving model to model/model-2400.ckpt ...
#
#
# Best model at step 2400:
#   train loss: 2.74e+04
#   test loss: 3.92e+04
#   test metric: [3.73e+00]
#
# 'train' took 7.946646 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2400      [2.74e+04, 4.32e+00]    [3.92e+04, 4.32e+00]    [3.73e+00]
# 2500      [2.71e+04, 3.83e+00]    [4.01e+04, 3.83e+00]    [3.59e+00]
# Epoch 2500: train loss improved from 2.74e+04 to 2.72e+04, saving model to model/model-2500.ckpt ...
#
#
# Best model at step 2500:
#   train loss: 2.72e+04
#   test loss: 4.01e+04
#   test metric: [3.59e+00]
#
# 'train' took 7.394750 s
#
# Training model...
#
# Step      Train loss              Test loss               Test metric
# 2500      [2.71e+04, 3.83e+00]    [4.01e+04, 3.83e+00]    [3.59e+00]
#
# Best model at step 2500:
#   train loss: 2.72e+04
#   test loss: 4.01e+04
#   test metric: [3.59e+00]
#
# 'train' took 6.025452 s
#
# Movie saved as movie_15_15.gif
# Saving loss history to /content/loss.dat ...
# Saving training data to /content/train.dat ...
# Saving test data to /content/test.dat ...
# Restoring model from model/model-2500.ckpt ...
#
# eps_l2 =  3.4498587
# eps_c =  3.2705286
# residual_l2 =  1.0566943
# residual_c =  3770.949
